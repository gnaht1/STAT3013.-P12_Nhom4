# %%
import pandas as pd

# %%
# Input Dataset
df = pd.read_excel('D:/Thái/Phân tích thống kê/STAT3013.-P12_Nhom4/Dataset/Silver_data_filtered.xlsx')

# %%
# Mean of the closing price of Silver
df['close'].mean()
# Out:
# np.float64(22.0004237991812)

# %%
# Median of the closing price of Silver
df['close'].median()
# Out:
# np.float64(22.921500205993652)

# %%
# Max/Min of the closing price of Silver
print(df['close'].max())
print(df['close'].min())
# Out:
# 32.20500183105469
# 11.73499965667725

# %%
# Var of the closing price of Silver
df['close'].var(ddof=1)
# Out:
# np.float64(15.893718509961792)

# %%
# Standard Deviation of the closing price of Silver
df['close'].std(ddof=1)
# Out:
# np.float64(3.9866926781433496)

# %%
# Q3 
df['close'].quantile(0.75)
# Out:
# np.float64(24.77475023269653)

# %%
# Q1 
df['close'].quantile(0.25)
# Out:
# np.float64(18.292500019073486)

# %%
# IQR 
IQR = df['close'].quantile(0.75) - df['close'].quantile(0.25)
IQR
# Out:
# np.float64(6.482250213623043)

# %%
# Upper Limit
upper_limit = df['close'].quantile(0.75) + 1.5*IQR
upper_limit
# Out:
# np.float64(34.498125553131096)

# %%
#3.11 Lower Limit
lower_limit  = df['close'].quantile(0.25) - 1.5*IQR
lower_limit
# Out:
# np.float64(8.569124698638921)

# %%
# Skewness
gdp_skewness = df['close'].skew()
gdp_skewness
# Out:
# np.float64(-0.3030048798391218)

# %%
# Kurtosis
gdp_kurtosis = df['close'].kurt()
gdp_kurtosis
# Out:
# np.float64(-0.710478372078748)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['close'], color='#c7675d', width=0.5, linewidth=2, showfliers=False)
plt.title('Box Plot of Closing Price of Silver (2019 - 2024)')
plt.xlabel('Close')
plt.show()

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['close'],color='#c7675d', bins=20, kde=True)
plt.title('Histogram of Closing Price of Silver (2019 - 2024)')
plt.xlabel('Close')
plt.ylabel('Frequency')
plt.show()
