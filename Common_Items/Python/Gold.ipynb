# %%
import pandas as pd

# %%
# Input Dataset
df = pd.read_excel('D:/Thái/Phân tích thống kê/STAT3013.-P12_Nhom4/Dataset/Gold_data_filtered.xlsx')

# %%
# Mean of the closing price of Gold
df['close'].mean()
# Out:
# np.float64(1795.5178466067553)

# %%
# Median of the closing price of Gold
df['close'].median()
# Out:
# np.float64(1813.900024414062)

# %%
# Median of the closing price of Gold
df['close'].mode()
# Out:
# 0    1815.900024
# Name: close, dtype: float64

# %%
# Max/Min of the closing price of Gold
print(df['close'].max())
print(df['close'].min())
# Out:
# 2433.89990234375
# 1269.300048828125

# %%
# Range of the closing price of Gold
df['close'].max() - df['close'].min()
# Out:
# np.float64(1164.599853515625)

# %%
# Var of the closing price of Gold
df['close'].var(ddof=1)
# Out:
# np.float64(52224.86856100322)

# %%
# Standard Deviation of the closing price of Gold
df['close'].std(ddof=1)
# Out:
# np.float64(228.52761006277385)

# %%
# Q3 
df['close'].quantile(0.75)
# Out:
# np.float64(1928.849975585937)

# %%
# Q1 
df['close'].quantile(0.25)
# Out:
# np.float64(1703.900024414062)

# %%
# IQR 
IQR = df['close'].quantile(0.75) - df['close'].quantile(0.25)
IQR
# Out:
# np.float64(224.949951171875)

# %%
# Upper Limit
upper_limit = df['close'].quantile(0.75) + 1.5*IQR
upper_limit
# Out:
# np.float64(2266.2749023437495)

# %%
#3.11 Lower Limit
lower_limit  = df['close'].quantile(0.25) - 1.5*IQR
lower_limit
# Out:
# np.float64(1366.4750976562495)

# %%
# Skewness
gdp_skewness = df['close'].skew()
gdp_skewness
# Out:
# np.float64(-0.1563270838488865)

# %%
# Kurtosis
gdp_kurtosis = df['close'].kurt()
gdp_kurtosis
# Out:
# np.float64(0.4713479475411013)

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['close'], color='#c7675d', width=0.5, linewidth=2, showfliers=True)
plt.title('Box Plot of Closing Price of Gold (2019 - 2024)')
plt.xlabel('Close')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns 

# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['close'],color='#c7675d', bins=20, kde=False)
plt.title('Histogram of Closing Price of Gold (2019 - 2024)')
plt.xlabel('Close')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['date'], y=df['close'], color='#c7675d', s=50)  

plt.title('Scatter Plot of Closing Price of Gold (2019 - 2024)')
plt.xlabel('Date')
plt.ylabel('Close')
plt.show()
