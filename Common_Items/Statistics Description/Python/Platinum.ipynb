# %%
import pandas as pd

# %%
# Input Dataset
df = pd.read_excel('E:/Code/STAT3013.-P12_Nhom4/Dataset/Platinum_data_filtered.xlsx')

# %%
# Mean of the closing price of Platinum
df['close'].mean()
# Out:
# np.float64(956.0891468361435)

# %%
# Median of the closing price of Platinum
df['close'].median()
# Out:
# np.float64(942.7000122070312)

# %%
# Mode of the closing price of Platinum
df['close'].mode()
# Out:
# 0    904.500000
# 1    933.400024
# Name: close, dtype: float64

# %%
# Max/Min of the closing price of Platinum
print(df['close'].max())
print(df['close'].min())
# Out:
# 1290.599975585938
# 595.9000244140625

# %%
# Range of the closing price of Platinum
df['close'].max() - df['close'].min()
# Out:
# np.float64(694.6999511718755)

# %%
# Var of the closing price of Platinum
df['close'].var(ddof=1)
# Out:
# np.float64(10755.83668835426)

# %%
# Standard Deviation of the closing price of Platinum
df['close'].std(ddof=1)
# Out:
# np.float64(103.71034995772727)

# %%
# Q3 
df['close'].quantile(0.75)
# Out:
# np.float64(1016.5500183105465)

# %%
# Q1 
df['close'].quantile(0.25)
# Out:
# np.float64(889.1999816894531)

# %%
# IQR 
IQR = df['close'].quantile(0.75) - df['close'].quantile(0.25)
IQR
# Out:
# np.float64(127.35003662109341)

# %%
# Upper Limit
upper_limit = df['close'].quantile(0.75) + 1.5*IQR
upper_limit
# Out:
# np.float64(1207.5750732421866)

# %%
#3.11 Lower Limit
lower_limit  = df['close'].quantile(0.25) - 1.5*IQR
lower_limit
# Out:
# np.float64(698.174926757813)

# %%
# Skewness
gdp_skewness = df['close'].skew()
gdp_skewness
# Out:
# np.float64(0.5126444412065524)

# %%
# Kurtosis
gdp_kurtosis = df['close'].kurt()
gdp_kurtosis
# Out:
# np.float64(0.7722294131723642)

# %%
# %pip install seaborn
import matplotlib.pyplot as plt
import seaborn as sns 

# Box Plot
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['close'], color='#c7675d', width=0.5, linewidth=2, showfliers=True)
plt.title('Box Plot of Closing Price of Platinum (2019 - 2024)')
plt.xlabel('Close')
plt.show()
# Out:
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#
# ...

# %%
# Histogram
plt.figure(figsize=(10, 6))
sns.histplot(df['close'],color='#c7675d', bins=20, kde=False)
plt.title('Histogram of Closing Price of Platinum (2019 - 2024)')
plt.xlabel('Close')
plt.ylabel('Frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter Plot
plt.figure(figsize=(10, 6))
sns.scatterplot(x=df['date'], y=df['close'], color='#c7675d', s=50)  # `s` là kích thước điểm

plt.title('Scatter Plot of Closing Price of Platinum (2019 - 2024)')
plt.xlabel('Date')
plt.ylabel('Close')
plt.show()
