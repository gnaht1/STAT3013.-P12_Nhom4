# %%
# %pip install numpy pandas matplotlib scikit-learn tensorflow openpyxl
# Out:
# Requirement already satisfied: numpy in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: tensorflow in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: openpyxl in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: et-xmlfile in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tensorflow --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
df = pd.read_excel('Platinum_data_filtered.xlsx')
df=df.set_index(pd.DatetimeIndex(df['date'].values))

# %%
    # Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

    # Format column Price to float




    # Create new Dataframe
df1 = pd.DataFrame(df, columns=['date', 'close'])
df1.drop('date', axis = 1, inplace = True)

    # Plot the 'price' column of the 'df' DataFrame
    plt.figure(figsize=(16,5))
    plt.plot(df1['close'])
    plt.title('Prices of Platinum')
    plt.show()

# %%
df
# Out:
#                  date        open        high         low       close  volume
# 2019-03-01 2019-03-01  861.599976  861.599976  861.599976  861.599976       0
# 2019-03-04 2019-03-04  836.799988  836.799988  836.799988  836.799988       0
# 2019-03-05 2019-03-05  840.200012  840.200012  835.900024  835.900024       2
# 2019-03-06 2019-03-06  828.299988  828.400024  826.200012  826.200012       2
# 2019-03-07 2019-03-07  825.000000  825.000000  815.299988  815.299988       4
# ...               ...         ...         ...         ...         ...     ...
# 2024-06-17 2024-06-17  963.200012  967.799988  961.200012  967.799988       8
# 2024-06-18 2024-06-18  974.099976  974.099976  974.099976  974.099976       8
# 2024-06-20 2024-06-20  981.599976  981.599976  981.599976  981.599976       8
# 2024-06-21 2024-06-21  993.700012  993.700012  993.700012  993.700012       8
# 2024-06-24 2024-06-24  999.099976  999.099976  999.099976  999.099976       8
#
# [1327 rows x 6 columns]

# %%
# Split dataset

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# Split the data
train_size = int(0.7 * len(sc_train))
test_size = int(0.2 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an LSTM layer with 50 units
model.add(LSTM(50,return_sequences=True))

# Add an LSTM layer with 50 units
model.add(LSTM(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_7_2_1.keras'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.23039, saving model to save_model_7_2_1.keras
# 17/17 - 3s - 188ms/step - loss: 0.2304
# Epoch 2/80
#
# Epoch 2: loss improved from 0.23039 to 0.07323, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0732
# Epoch 3/80
#
# Epoch 3: loss improved from 0.07323 to 0.06202, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 42ms/step - loss: 0.0620
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06202 to 0.05658, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0566
# Epoch 5/80
#
# Epoch 5: loss improved from 0.05658 to 0.05563, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 42ms/step - loss: 0.0556
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.05563
# 17/17 - 1s - 42ms/step - loss: 0.0582
# Epoch 7/80
#
# Epoch 7: loss did not improve from 0.05563
# 17/17 - 1s - 42ms/step - loss: 0.0580
# Epoch 8/80
#
# Epoch 8: loss improved from 0.05563 to 0.05322, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0532
# Epoch 9/80
#
# Epoch 9: loss improved from 0.05322 to 0.04685, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 42ms/step - loss: 0.0468
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.04685
# 17/17 - 1s - 41ms/step - loss: 0.0474
# Epoch 11/80
#
# Epoch 11: loss did not improve from 0.04685
# 17/17 - 1s - 41ms/step - loss: 0.0512
# Epoch 12/80
#
# Epoch 12: loss improved from 0.04685 to 0.04665, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0466
# Epoch 13/80
#
# Epoch 13: loss improved from 0.04665 to 0.04566, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0457
# Epoch 14/80
#
# Epoch 14: loss improved from 0.04566 to 0.04565, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0456
# Epoch 15/80
#
# Epoch 15: loss improved from 0.04565 to 0.04342, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0434
# Epoch 16/80
#
# Epoch 16: loss improved from 0.04342 to 0.04293, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0429
# Epoch 17/80
#
# Epoch 17: loss improved from 0.04293 to 0.04201, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0420
# Epoch 18/80
#
# Epoch 18: loss improved from 0.04201 to 0.04149, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0415
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.04149
# 17/17 - 1s - 43ms/step - loss: 0.0429
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.04149
# 17/17 - 1s - 42ms/step - loss: 0.0431
# Epoch 21/80
#
# Epoch 21: loss improved from 0.04149 to 0.04131, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0413
# Epoch 22/80
#
# Epoch 22: loss improved from 0.04131 to 0.03973, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0397
# Epoch 23/80
#
# Epoch 23: loss improved from 0.03973 to 0.03867, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0387
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.03867
# 17/17 - 1s - 42ms/step - loss: 0.0404
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.03867
# 17/17 - 1s - 43ms/step - loss: 0.0400
# Epoch 26/80
#
# Epoch 26: loss improved from 0.03867 to 0.03746, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0375
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.03746
# 17/17 - 1s - 41ms/step - loss: 0.0421
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.03746
# 17/17 - 1s - 41ms/step - loss: 0.0384
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.03746
# 17/17 - 1s - 42ms/step - loss: 0.0375
# Epoch 30/80
#
# Epoch 30: loss improved from 0.03746 to 0.03564, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 42ms/step - loss: 0.0356
# Epoch 31/80
#
# Epoch 31: loss improved from 0.03564 to 0.03504, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 42ms/step - loss: 0.0350
# Epoch 32/80
#
# Epoch 32: loss improved from 0.03504 to 0.03427, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0343
# Epoch 33/80
#
# Epoch 33: loss improved from 0.03427 to 0.03416, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0342
# Epoch 34/80
#
# Epoch 34: loss improved from 0.03416 to 0.03403, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0340
# Epoch 35/80
#
# Epoch 35: loss improved from 0.03403 to 0.03215, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0322
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.03215
# 17/17 - 1s - 42ms/step - loss: 0.0322
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.03215
# 17/17 - 1s - 42ms/step - loss: 0.0330
# Epoch 38/80
#
# Epoch 38: loss improved from 0.03215 to 0.02949, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0295
# Epoch 39/80
#
# Epoch 39: loss improved from 0.02949 to 0.02920, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 43ms/step - loss: 0.0292
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.02920
# 17/17 - 1s - 40ms/step - loss: 0.0297
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.02920
# 17/17 - 1s - 45ms/step - loss: 0.0311
# Epoch 42/80
#
# Epoch 42: loss improved from 0.02920 to 0.02787, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0279
# Epoch 43/80
#
# Epoch 43: loss improved from 0.02787 to 0.02654, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0265
# Epoch 44/80
#
# Epoch 44: loss improved from 0.02654 to 0.02615, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0262
# Epoch 45/80
#
# Epoch 45: loss improved from 0.02615 to 0.02521, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0252
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.02521
# 17/17 - 1s - 44ms/step - loss: 0.0267
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02521
# 17/17 - 1s - 43ms/step - loss: 0.0260
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02521
# 17/17 - 1s - 43ms/step - loss: 0.0260
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.02521
# 17/17 - 1s - 42ms/step - loss: 0.0277
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.02521
# 17/17 - 1s - 42ms/step - loss: 0.0276
# Epoch 51/80
#
# Epoch 51: loss improved from 0.02521 to 0.02437, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0244
# Epoch 52/80
#
# Epoch 52: loss improved from 0.02437 to 0.02424, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0242
# Epoch 53/80
#
# Epoch 53: loss improved from 0.02424 to 0.02400, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0240
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02400
# 17/17 - 1s - 42ms/step - loss: 0.0242
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02400
# 17/17 - 1s - 41ms/step - loss: 0.0291
# Epoch 56/80
#
# Epoch 56: loss improved from 0.02400 to 0.02381, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0238
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02381
# 17/17 - 1s - 47ms/step - loss: 0.0263
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02381
# 17/17 - 1s - 45ms/step - loss: 0.0269
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02381
# 17/17 - 1s - 43ms/step - loss: 0.0240
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02381
# 17/17 - 1s - 45ms/step - loss: 0.0265
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.02381
# 17/17 - 1s - 45ms/step - loss: 0.0246
# Epoch 62/80
#
# Epoch 62: loss improved from 0.02381 to 0.02329, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 49ms/step - loss: 0.0233
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02329
# 17/17 - 1s - 45ms/step - loss: 0.0237
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02329
# 17/17 - 1s - 42ms/step - loss: 0.0238
# Epoch 65/80
#
# Epoch 65: loss improved from 0.02329 to 0.02287, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0229
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02287
# 17/17 - 1s - 43ms/step - loss: 0.0232
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02287
# 17/17 - 1s - 41ms/step - loss: 0.0236
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02287
# 17/17 - 1s - 41ms/step - loss: 0.0244
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02287
# 17/17 - 1s - 41ms/step - loss: 0.0258
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02287
# 17/17 - 1s - 43ms/step - loss: 0.0238
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02287
# 17/17 - 1s - 47ms/step - loss: 0.0319
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02287
# 17/17 - 1s - 46ms/step - loss: 0.0266
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02287
# 17/17 - 1s - 42ms/step - loss: 0.0249
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02287
# 17/17 - 1s - 42ms/step - loss: 0.0248
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02287
# 17/17 - 1s - 43ms/step - loss: 0.0243
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02287
# 17/17 - 1s - 43ms/step - loss: 0.0233
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02287
# 17/17 - 1s - 42ms/step - loss: 0.0232
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02287
# 17/17 - 1s - 41ms/step - loss: 0.0235
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02287
# 17/17 - 1s - 42ms/step - loss: 0.0248
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02287
# 17/17 - 1s - 41ms/step - loss: 0.0236

# %%
from keras.models import load_model

# Reshape y_train to 2D if it's 1D, as MinMaxScaler expects 2D input
y_train = y_train.reshape(-1, 1)

# Transform the y_train array back to the original scale
y_train_original = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_7_2_1.keras')  # Đảm bảo đuôi đúng như đã lưu

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict_original = sc.inverse_transform(y_train_predict)

# Kiểm tra kết quả
print(f"Original y_train shape: {y_train_original.shape}")
print(f"Predicted y_train shape: {y_train_predict_original.shape}")
# Out:
# 26/26 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Original y_train shape: (828, 1)
# Predicted y_train shape: (828, 1)

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.4728660185535636, 0.4578954914986548, 0.42881817232948505, 0.43184111283430493, 0.4423492290082798, 0.40808985162841815, 0.41845396804980206, 0.3965740886195033, 0.4249315847423165, 0.3984453825367922, 0.42507558449490745, 0.4364473477512314, 0.4486828459482035, 0.45170578645302295, 0.4161508505913387, 0.4401900234441083, 0.44637972848974017, 0.40434717593554126, 0.4273787019533708, 0.40996114554570684, 0.40880958681647517, 0.41499929186210704, 0.43846264142111124, 0.41370373338028443, 0.4531452568291374, 0.46667622564963285, 0.4550165507464261, 0.4920109569842248, 0.47430548892967805, 0.4986324855710311, 0.4858212519385927, 0.497049103300625, 0.4643731081911695, 0.4361595239626479, 0.4335684069990027, 0.4531452568291374, 0.4321289366228882, 0.44738737532468, 0.45012231632431776, 0.43184111283430493, 0.44882684570079423, 0.4390384647148764, 0.4696991661544523, 0.4866848990209418, 0.49503380963074517, 0.4787678119523129, 0.5268461576578518, 0.5419605966070524, 0.5307326573867215, 0.5472865667120363, 0.5680149752714025, 0.5382179209141758, 0.5298690103043724, 0.4992083088647965, 0.5029508966993741, 0.48682881091523367, 0.4696991661544523, 0.4574636679574804, 0.4521376099941974, 0.4574636679574804, 0.45832731503982926, 0.5156182184375206, 0.497049103300625, 0.5082769546626571, 0.5193608941303975, 0.5235353055061496, 0.5231034819649751, 0.5549158299920816, 0.5508852426523223, 0.5596660646615992, 0.5832733261148957, 0.5893191192662355, 0.6382611999124224, 0.6728084889391668, 0.6758313415856865, 0.7034691025204438, 0.6676262550118761, 0.6633078438835331, 0.6451705522878126, 0.6186842622239883, 0.6317835832199077, 0.6705051957641048, 0.6431552586179321, 0.6290485543619702, 0.6359579067373604, 0.6083201458026044, 0.5695983575418089, 0.5759320623400315, 0.5936375303945784, 0.535338980161947, 0.5421045085013443, 0.5177774240016924, 0.5359148034557124, 0.5115877189560603, 0.5173456004605177, 0.535338980161947, 0.5444076259598076, 0.5552036537806653, 0.5726212980466283, 0.5803943853626665]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.5646291971206665], [0.5479000210762024], [0.5305882692337036], [0.5151407718658447], [0.5026231408119202], [0.4928061366081238], [0.48484915494918823], [0.47777679562568665], [0.47077834606170654], [0.46334147453308105], [0.4552608132362366], [0.4465716779232025], [0.43745288252830505], [0.4281347692012787], [0.4188315272331238], [0.4097045958042145], [0.40085336565971375], [0.39232319593429565], [0.3841230869293213], [0.3762431740760803], [0.3686694800853729], [0.3613925576210022], [0.3544110953807831], [0.3477315902709961], [0.34136536717414856], [0.3353254497051239], [0.3296235203742981], [0.32426711916923523], [0.3192591071128845], [0.3145969808101654]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[988.14790008]
#  [976.5261423 ]
#  [964.49966914]
#  [953.76829348]
#  [945.07229579]
#  [938.25242345]
#  [932.72470868]
#  [927.81154101]
#  [922.94971844]
#  [917.78332415]
#  [912.16968914]
#  [906.13334726]
#  [899.79852055]
#  [893.32522767]
#  [886.86226593]
#  [880.52178711]
#  [874.37283796]
#  [868.44692947]
#  [862.75031415]
#  [857.27613907]
#  [852.01469423]
#  [846.95941655]
#  [842.10939507]
#  [837.4691432 ]
#  [833.04652832]
#  [828.85059795]
#  [824.88946792]
#  [821.16837627]
#  [817.68931054]
#  [814.45053162]]

# %%
from sklearn.preprocessing import MinMaxScaler

# Khởi tạo MinMaxScaler và huấn luyện với dữ liệu ban đầu
sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])  # Thay 'close' bằng tên cột chứa giá trị cần chuẩn hóa trong dữ liệu của bạn
# Out:
# MinMaxScaler()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['close']).set_index(pd.Series(datelist_future))

# Split the data into train, test, and validate
train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a plot
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 297.8875835048976
# Lower Bound of Future Prediction: [[ 714.51131422]
#  [ 725.73870846]
#  [ 738.11043606]
#  [ 750.78663185]
#  [ 763.84704638]
#  [ 777.43855151]
#  [ 791.70226345]
#  [ 806.73698014]
#  [ 822.57284612]
#  [ 839.17118692]
#  [ 856.44334943]
#  [ 874.27774086]
#  [ 892.56289263]
#  [ 911.2026983 ]
#  [ 930.11827688]
#  [ 949.24296254]
#  [ 968.51265673]
#  [ 987.85812635]
#  [1007.20247798]
#  [1026.46235862]
#  [1045.5555333 ]
#  [1064.40589531]
#  [1082.94926328]
#  [1101.13387801]
#  [1118.92056818]
#  [1136.27778137]
#  [1153.18001068]
#  [1169.60497893]
#  [1185.53347314]
#  [1200.94917879]]
# Upper Bound of Future Prediction: [[1310.28648123]
#  [1321.51387547]
#  [1333.88560306]
#  [1346.56179886]
#  [1359.62221339]
#  [1373.21371852]
#  [1387.47743046]
#  [1402.51214715]
#  [1418.34801313]
#  [1434.94635393]
#  [1452.21851644]
#  [1470.05290787]
#  [1488.33805964]
#  [1506.97786531]
#  [1525.89344389]
#  [1545.01812955]
#  [1564.28782374]
#  [1583.63329336]
#  [1602.97764499]
#  [1622.23752563]
#  [1641.33070031]
#  [1660.18106232]
#  [1678.72443029]
#  [1696.90904502]
#  [1714.69573519]
#  [1732.05294838]
#  [1748.95517769]
#  [1765.38014594]
#  [1781.30864015]
#  [1796.7243458 ]]
# Confidence Score: 0.5212047002591855

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  13.74504578788324
# MAPE:  1.4089394971942708
# RMSE:  17.236368277446537
#
# ** Validate **
# MAE:  12.75351043245687
# MAPE:  1.341938302900869
# RMSE:  15.521839320271758

# %%
# Split dataset 6-3-1

# %%
#  Split data (6-3-1)
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import ModelCheckpoint
import numpy as np


x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))  

# Build the model
model = Sequential()

# Add LSTM layers
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))

# Add Dense output layer
model.add(Dense(1))

# Compile the model
model.compile(loss='mean_absolute_error', optimizer='adam')

# Set the filename to use for saving the best model
save_model = 'save_model_6_3_1.keras'

# Create a ModelCheckpoint callback to save the best model based on 'loss'
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.19495, saving model to save_model_6_3_1.keras
# 14/14 - 3s - 196ms/step - loss: 0.1949
# Epoch 2/80
#
# Epoch 2: loss improved from 0.19495 to 0.08173, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0817
# Epoch 3/80
#
# Epoch 3: loss improved from 0.08173 to 0.06967, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0697
# Epoch 4/80
#
# Epoch 4: loss improved from 0.06967 to 0.06081, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0608
# Epoch 5/80
#
# Epoch 5: loss improved from 0.06081 to 0.05828, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0583
# Epoch 6/80
#
# Epoch 6: loss improved from 0.05828 to 0.05417, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0542
# Epoch 7/80
#
# Epoch 7: loss improved from 0.05417 to 0.05239, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0524
# Epoch 8/80
#
# Epoch 8: loss improved from 0.05239 to 0.05210, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0521
# Epoch 9/80
#
# Epoch 9: loss improved from 0.05210 to 0.05047, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0505
# Epoch 10/80
#
# Epoch 10: loss improved from 0.05047 to 0.04934, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0493
# Epoch 11/80
#
# Epoch 11: loss improved from 0.04934 to 0.04681, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0468
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.04681
# 14/14 - 1s - 43ms/step - loss: 0.0476
# Epoch 13/80
#
# Epoch 13: loss improved from 0.04681 to 0.04650, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0465
# Epoch 14/80
#
# Epoch 14: loss improved from 0.04650 to 0.04369, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0437
# Epoch 15/80
#
# Epoch 15: loss improved from 0.04369 to 0.04251, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0425
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.04251
# 14/14 - 1s - 44ms/step - loss: 0.0437
# Epoch 17/80
#
# Epoch 17: loss improved from 0.04251 to 0.04206, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0421
# Epoch 18/80
#
# Epoch 18: loss improved from 0.04206 to 0.04165, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0417
# Epoch 19/80
#
# Epoch 19: loss did not improve from 0.04165
# 14/14 - 1s - 43ms/step - loss: 0.0443
# Epoch 20/80
#
# Epoch 20: loss improved from 0.04165 to 0.04153, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0415
# Epoch 21/80
#
# Epoch 21: loss improved from 0.04153 to 0.03963, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 44ms/step - loss: 0.0396
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.03963
# 14/14 - 1s - 43ms/step - loss: 0.0402
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.03963
# 14/14 - 1s - 43ms/step - loss: 0.0401
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.03963
# 14/14 - 1s - 43ms/step - loss: 0.0418
# Epoch 25/80
#
# Epoch 25: loss improved from 0.03963 to 0.03931, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0393
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.03931
# 14/14 - 1s - 43ms/step - loss: 0.0405
# Epoch 27/80
#
# Epoch 27: loss improved from 0.03931 to 0.03794, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0379
# Epoch 28/80
#
# Epoch 28: loss improved from 0.03794 to 0.03742, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0374
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.03742
# 14/14 - 1s - 44ms/step - loss: 0.0375
# Epoch 30/80
#
# Epoch 30: loss improved from 0.03742 to 0.03739, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0374
# Epoch 31/80
#
# Epoch 31: loss improved from 0.03739 to 0.03706, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0371
# Epoch 32/80
#
# Epoch 32: loss improved from 0.03706 to 0.03642, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0364
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.03642
# 14/14 - 1s - 44ms/step - loss: 0.0372
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.03642
# 14/14 - 1s - 43ms/step - loss: 0.0374
# Epoch 35/80
#
# Epoch 35: loss improved from 0.03642 to 0.03575, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0358
# Epoch 36/80
#
# Epoch 36: loss improved from 0.03575 to 0.03377, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0338
# Epoch 37/80
#
# Epoch 37: loss improved from 0.03377 to 0.03301, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0330
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.03301
# 14/14 - 1s - 43ms/step - loss: 0.0341
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.03301
# 14/14 - 1s - 43ms/step - loss: 0.0430
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.03301
# 14/14 - 1s - 43ms/step - loss: 0.0340
# Epoch 41/80
#
# Epoch 41: loss improved from 0.03301 to 0.03189, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0319
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.03189
# 14/14 - 1s - 43ms/step - loss: 0.0320
# Epoch 43/80
#
# Epoch 43: loss improved from 0.03189 to 0.03178, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0318
# Epoch 44/80
#
# Epoch 44: loss improved from 0.03178 to 0.02865, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0286
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.02865
# 14/14 - 1s - 44ms/step - loss: 0.0290
# Epoch 46/80
#
# Epoch 46: loss improved from 0.02865 to 0.02841, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0284
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.02841
# 14/14 - 1s - 44ms/step - loss: 0.0292
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.02841
# 14/14 - 1s - 44ms/step - loss: 0.0297
# Epoch 49/80
#
# Epoch 49: loss improved from 0.02841 to 0.02764, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0276
# Epoch 50/80
#
# Epoch 50: loss improved from 0.02764 to 0.02583, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0258
# Epoch 51/80
#
# Epoch 51: loss improved from 0.02583 to 0.02491, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0249
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0275
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.02491
# 14/14 - 1s - 46ms/step - loss: 0.0266
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0251
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0276
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0277
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0256
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02491
# 14/14 - 1s - 44ms/step - loss: 0.0250
# Epoch 59/80
#
# Epoch 59: loss improved from 0.02491 to 0.02426, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0243
# Epoch 60/80
#
# Epoch 60: loss improved from 0.02426 to 0.02411, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0241
# Epoch 61/80
#
# Epoch 61: loss improved from 0.02411 to 0.02400, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 46ms/step - loss: 0.0240
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.02400
# 14/14 - 1s - 43ms/step - loss: 0.0246
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02400
# 14/14 - 1s - 43ms/step - loss: 0.0274
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02400
# 14/14 - 1s - 43ms/step - loss: 0.0292
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02400
# 14/14 - 1s - 43ms/step - loss: 0.0271
# Epoch 66/80
#
# Epoch 66: loss improved from 0.02400 to 0.02328, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0233
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0233
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.02328
# 14/14 - 1s - 44ms/step - loss: 0.0238
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0269
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0278
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0259
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0233
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0239
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0253
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02328
# 14/14 - 1s - 43ms/step - loss: 0.0237
# Epoch 76/80
#
# Epoch 76: loss improved from 0.02328 to 0.02319, saving model to save_model_6_3_1.keras
# 14/14 - 1s - 45ms/step - loss: 0.0232
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02319
# 14/14 - 1s - 43ms/step - loss: 0.0254
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02319
# 14/14 - 1s - 43ms/step - loss: 0.0252
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02319
# 14/14 - 1s - 43ms/step - loss: 0.0237
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02319
# 14/14 - 1s - 44ms/step - loss: 0.0260

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_6_3_1.keras')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 11/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.4728660185535636, 0.4578954914986548, 0.42881817232948505, 0.43184111283430493, 0.4423492290082798, 0.40808985162841815, 0.41845396804980206, 0.3965740886195033, 0.4249315847423165, 0.3984453825367922, 0.42507558449490745, 0.4364473477512314, 0.4486828459482035, 0.45170578645302295, 0.4161508505913387, 0.4401900234441083, 0.44637972848974017, 0.40434717593554126, 0.4273787019533708, 0.40996114554570684, 0.40880958681647517, 0.41499929186210704, 0.43846264142111124, 0.41370373338028443, 0.4531452568291374, 0.46667622564963285, 0.4550165507464261, 0.4920109569842248, 0.47430548892967805, 0.4986324855710311, 0.4858212519385927, 0.497049103300625, 0.4643731081911695, 0.4361595239626479, 0.4335684069990027, 0.4531452568291374, 0.4321289366228882, 0.44738737532468, 0.45012231632431776, 0.43184111283430493, 0.44882684570079423, 0.4390384647148764, 0.4696991661544523, 0.4866848990209418, 0.49503380963074517, 0.4787678119523129, 0.5268461576578518, 0.5419605966070524, 0.5307326573867215, 0.5472865667120363, 0.5680149752714025, 0.5382179209141758, 0.5298690103043724, 0.4992083088647965, 0.5029508966993741, 0.48682881091523367, 0.4696991661544523, 0.4574636679574804, 0.4521376099941974, 0.4574636679574804, 0.45832731503982926, 0.5156182184375206, 0.497049103300625, 0.5082769546626571, 0.5193608941303975, 0.5235353055061496, 0.5231034819649751, 0.5549158299920816, 0.5508852426523223, 0.5596660646615992, 0.5832733261148957, 0.5893191192662355, 0.6382611999124224, 0.6728084889391668, 0.6758313415856865, 0.7034691025204438, 0.6676262550118761, 0.6633078438835331, 0.6451705522878126, 0.6186842622239883, 0.6317835832199077, 0.6705051957641048, 0.6431552586179321, 0.6290485543619702, 0.6359579067373604, 0.6083201458026044, 0.5695983575418089, 0.5759320623400315, 0.5936375303945784, 0.535338980161947, 0.5421045085013443, 0.5177774240016924, 0.5359148034557124, 0.5115877189560603, 0.5173456004605177, 0.535338980161947, 0.5444076259598076, 0.5552036537806653, 0.5726212980466283, 0.5803943853626665]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.5601177215576172], [0.5420916676521301], [0.5247534513473511], [0.5107340216636658], [0.4999220669269562], [0.4915013313293457], [0.48440709710121155], [0.47766441106796265], [0.4705803096294403], [0.4628032445907593], [0.4542885422706604], [0.44521021842956543], [0.4358576238155365], [0.4265441298484802], [0.4175413250923157], [0.4090437591075897], [0.40116119384765625], [0.39392977952957153], [0.3873325288295746], [0.3813227415084839], [0.37584245204925537], [0.3708368241786957], [0.36626023054122925], [0.362077921628952], [0.358265221118927], [0.35480257868766785], [0.35167261958122253], [0.3488573133945465], [0.3463360667228699], [0.34408530592918396]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[985.01377823]
#  [972.49107946]
#  [960.44622144]
#  [950.70692433]
#  [943.1958599 ]
#  [937.34597529]
#  [932.41761112]
#  [927.73346746]
#  [922.81214254]
#  [917.40941583]
#  [911.49425255]
#  [905.18754142]
#  [898.6902944 ]
#  [892.22021059]
#  [885.96596257]
#  [880.06270389]
#  [874.58668619]
#  [869.56302302]
#  [864.97991328]
#  [860.80491432]
#  [856.9977575 ]
#  [853.52034806]
#  [850.34098869]
#  [847.43553889]
#  [844.78685603]
#  [842.3813585 ]
#  [840.20697607]
#  [838.251183  ]
#  [836.49967306]
#  [834.93606964]]

# %%
from sklearn.preprocessing import MinMaxScaler


sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])
# Out:
# MinMaxScaler()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['close']).set_index(pd.Series(datelist_future))

# Split the data into train, test, and validate
train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a plot
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 297.8875835048976
# Lower Bound of Future Prediction: [[ 714.51131422]
#  [ 725.73870846]
#  [ 738.11043606]
#  [ 750.78663185]
#  [ 763.84704638]
#  [ 777.43855151]
#  [ 791.70226345]
#  [ 806.73698014]
#  [ 822.57284612]
#  [ 839.17118692]
#  [ 856.44334943]
#  [ 874.27774086]
#  [ 892.56289263]
#  [ 911.2026983 ]
#  [ 930.11827688]
#  [ 949.24296254]
#  [ 968.51265673]
#  [ 987.85812635]
#  [1007.20247798]
#  [1026.46235862]
#  [1045.5555333 ]
#  [1064.40589531]
#  [1082.94926328]
#  [1101.13387801]
#  [1118.92056818]
#  [1136.27778137]
#  [1153.18001068]
#  [1169.60497893]
#  [1185.53347314]
#  [1200.94917879]]
# Upper Bound of Future Prediction: [[1310.28648123]
#  [1321.51387547]
#  [1333.88560306]
#  [1346.56179886]
#  [1359.62221339]
#  [1373.21371852]
#  [1387.47743046]
#  [1402.51214715]
#  [1418.34801313]
#  [1434.94635393]
#  [1452.21851644]
#  [1470.05290787]
#  [1488.33805964]
#  [1506.97786531]
#  [1525.89344389]
#  [1545.01812955]
#  [1564.28782374]
#  [1583.63329336]
#  [1602.97764499]
#  [1622.23752563]
#  [1641.33070031]
#  [1660.18106232]
#  [1678.72443029]
#  [1696.90904502]
#  [1714.69573519]
#  [1732.05294838]
#  [1748.95517769]
#  [1765.38014594]
#  [1781.30864015]
#  [1796.7243458 ]]
# Confidence Score: 0.5212047002591855

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  14.37813456933102
# MAPE:  1.5088532465344549
# RMSE:  18.034196420879148
#
# ** Validate **
# MAE:  12.81421127892976
# MAPE:  1.3507736316782244
# RMSE:  15.517040813627426

# %%
# Split dataset 5-3-2

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)# Split data



train_size = int(0.5 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an LSTM layer with 50 units
model.add(LSTM(50,return_sequences=True))

# Add an LSTM layer with 50 units
model.add(LSTM(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.keras'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.28351, saving model to save_model_5_3_2.keras
# 12/12 - 3s - 234ms/step - loss: 0.2835
# Epoch 2/80
#
# Epoch 2: loss improved from 0.28351 to 0.10060, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.1006
# Epoch 3/80
#
# Epoch 3: loss improved from 0.10060 to 0.07458, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0746
# Epoch 4/80
#
# Epoch 4: loss improved from 0.07458 to 0.06255, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0625
# Epoch 5/80
#
# Epoch 5: loss improved from 0.06255 to 0.05654, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0565
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.05654
# 12/12 - 1s - 42ms/step - loss: 0.0577
# Epoch 7/80
#
# Epoch 7: loss improved from 0.05654 to 0.05233, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0523
# Epoch 8/80
#
# Epoch 8: loss improved from 0.05233 to 0.05006, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0501
# Epoch 9/80
#
# Epoch 9: loss did not improve from 0.05006
# 12/12 - 1s - 42ms/step - loss: 0.0526
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.05006
# 12/12 - 1s - 43ms/step - loss: 0.0503
# Epoch 11/80
#
# Epoch 11: loss improved from 0.05006 to 0.04851, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0485
# Epoch 12/80
#
# Epoch 12: loss improved from 0.04851 to 0.04798, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0480
# Epoch 13/80
#
# Epoch 13: loss improved from 0.04798 to 0.04533, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0453
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.04533
# 12/12 - 1s - 43ms/step - loss: 0.0458
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.04533
# 12/12 - 1s - 42ms/step - loss: 0.0479
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.04533
# 12/12 - 1s - 42ms/step - loss: 0.0483
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.04533
# 12/12 - 1s - 42ms/step - loss: 0.0503
# Epoch 18/80
#
# Epoch 18: loss improved from 0.04533 to 0.04299, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0430
# Epoch 19/80
#
# Epoch 19: loss improved from 0.04299 to 0.04248, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0425
# Epoch 20/80
#
# Epoch 20: loss improved from 0.04248 to 0.04102, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0410
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.04102
# 12/12 - 1s - 43ms/step - loss: 0.0418
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.04102
# 12/12 - 1s - 43ms/step - loss: 0.0418
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.04102
# 12/12 - 1s - 43ms/step - loss: 0.0426
# Epoch 24/80
#
# Epoch 24: loss did not improve from 0.04102
# 12/12 - 1s - 43ms/step - loss: 0.0477
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.04102
# 12/12 - 1s - 44ms/step - loss: 0.0435
# Epoch 26/80
#
# Epoch 26: loss improved from 0.04102 to 0.04021, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0402
# Epoch 27/80
#
# Epoch 27: loss improved from 0.04021 to 0.03985, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0399
# Epoch 28/80
#
# Epoch 28: loss improved from 0.03985 to 0.03891, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0389
# Epoch 29/80
#
# Epoch 29: loss improved from 0.03891 to 0.03865, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0387
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.03865
# 12/12 - 1s - 44ms/step - loss: 0.0408
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.03865
# 12/12 - 1s - 43ms/step - loss: 0.0399
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.03865
# 12/12 - 1s - 43ms/step - loss: 0.0400
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.03865
# 12/12 - 1s - 44ms/step - loss: 0.0394
# Epoch 34/80
#
# Epoch 34: loss improved from 0.03865 to 0.03731, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0373
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.03731
# 12/12 - 1s - 44ms/step - loss: 0.0375
# Epoch 36/80
#
# Epoch 36: loss improved from 0.03731 to 0.03699, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0370
# Epoch 37/80
#
# Epoch 37: loss improved from 0.03699 to 0.03665, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0366
# Epoch 38/80
#
# Epoch 38: loss improved from 0.03665 to 0.03644, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0364
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.03644
# 12/12 - 1s - 44ms/step - loss: 0.0367
# Epoch 40/80
#
# Epoch 40: loss improved from 0.03644 to 0.03638, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0364
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.03638
# 12/12 - 1s - 43ms/step - loss: 0.0397
# Epoch 42/80
#
# Epoch 42: loss improved from 0.03638 to 0.03552, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0355
# Epoch 43/80
#
# Epoch 43: loss improved from 0.03552 to 0.03436, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0344
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.03436
# 12/12 - 1s - 43ms/step - loss: 0.0359
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.03436
# 12/12 - 1s - 44ms/step - loss: 0.0355
# Epoch 46/80
#
# Epoch 46: loss improved from 0.03436 to 0.03432, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0343
# Epoch 47/80
#
# Epoch 47: loss improved from 0.03432 to 0.03253, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0325
# Epoch 48/80
#
# Epoch 48: loss improved from 0.03253 to 0.03189, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0319
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.03189
# 12/12 - 1s - 43ms/step - loss: 0.0360
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.03189
# 12/12 - 1s - 43ms/step - loss: 0.0333
# Epoch 51/80
#
# Epoch 51: loss improved from 0.03189 to 0.03176, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0318
# Epoch 52/80
#
# Epoch 52: loss improved from 0.03176 to 0.03117, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0312
# Epoch 53/80
#
# Epoch 53: loss improved from 0.03117 to 0.02935, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0293
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.02935
# 12/12 - 1s - 44ms/step - loss: 0.0302
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.02935
# 12/12 - 1s - 44ms/step - loss: 0.0343
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.02935
# 12/12 - 1s - 44ms/step - loss: 0.0301
# Epoch 57/80
#
# Epoch 57: loss improved from 0.02935 to 0.02809, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0281
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.02809
# 12/12 - 1s - 42ms/step - loss: 0.0282
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.02809
# 12/12 - 1s - 43ms/step - loss: 0.0291
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.02809
# 12/12 - 1s - 44ms/step - loss: 0.0315
# Epoch 61/80
#
# Epoch 61: loss improved from 0.02809 to 0.02716, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0272
# Epoch 62/80
#
# Epoch 62: loss improved from 0.02716 to 0.02666, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0267
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.02666
# 12/12 - 1s - 43ms/step - loss: 0.0268
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.02666
# 12/12 - 1s - 43ms/step - loss: 0.0305
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.02666
# 12/12 - 1s - 44ms/step - loss: 0.0302
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.02666
# 12/12 - 1s - 44ms/step - loss: 0.0271
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.02666
# 12/12 - 1s - 43ms/step - loss: 0.0271
# Epoch 68/80
#
# Epoch 68: loss improved from 0.02666 to 0.02460, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0246
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.02460
# 12/12 - 1s - 43ms/step - loss: 0.0250
# Epoch 70/80
#
# Epoch 70: loss improved from 0.02460 to 0.02444, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0244
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.02444
# 12/12 - 1s - 43ms/step - loss: 0.0257
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.02444
# 12/12 - 1s - 43ms/step - loss: 0.0251
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.02444
# 12/12 - 1s - 44ms/step - loss: 0.0259
# Epoch 74/80
#
# Epoch 74: loss improved from 0.02444 to 0.02441, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0244
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.02441
# 12/12 - 1s - 43ms/step - loss: 0.0259
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.02441
# 12/12 - 1s - 43ms/step - loss: 0.0264
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.02441
# 12/12 - 1s - 43ms/step - loss: 0.0253
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.02441
# 12/12 - 1s - 43ms/step - loss: 0.0247
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.02441
# 12/12 - 1s - 43ms/step - loss: 0.0250
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.02441
# 12/12 - 1s - 44ms/step - loss: 0.0248

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_5_3_2.keras')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.4728660185535636, 0.4578954914986548, 0.42881817232948505, 0.43184111283430493, 0.4423492290082798, 0.40808985162841815, 0.41845396804980206, 0.3965740886195033, 0.4249315847423165, 0.3984453825367922, 0.42507558449490745, 0.4364473477512314, 0.4486828459482035, 0.45170578645302295, 0.4161508505913387, 0.4401900234441083, 0.44637972848974017, 0.40434717593554126, 0.4273787019533708, 0.40996114554570684, 0.40880958681647517, 0.41499929186210704, 0.43846264142111124, 0.41370373338028443, 0.4531452568291374, 0.46667622564963285, 0.4550165507464261, 0.4920109569842248, 0.47430548892967805, 0.4986324855710311, 0.4858212519385927, 0.497049103300625, 0.4643731081911695, 0.4361595239626479, 0.4335684069990027, 0.4531452568291374, 0.4321289366228882, 0.44738737532468, 0.45012231632431776, 0.43184111283430493, 0.44882684570079423, 0.4390384647148764, 0.4696991661544523, 0.4866848990209418, 0.49503380963074517, 0.4787678119523129, 0.5268461576578518, 0.5419605966070524, 0.5307326573867215, 0.5472865667120363, 0.5680149752714025, 0.5382179209141758, 0.5298690103043724, 0.4992083088647965, 0.5029508966993741, 0.48682881091523367, 0.4696991661544523, 0.4574636679574804, 0.4521376099941974, 0.4574636679574804, 0.45832731503982926, 0.5156182184375206, 0.497049103300625, 0.5082769546626571, 0.5193608941303975, 0.5235353055061496, 0.5231034819649751, 0.5549158299920816, 0.5508852426523223, 0.5596660646615992, 0.5832733261148957, 0.5893191192662355, 0.6382611999124224, 0.6728084889391668, 0.6758313415856865, 0.7034691025204438, 0.6676262550118761, 0.6633078438835331, 0.6451705522878126, 0.6186842622239883, 0.6317835832199077, 0.6705051957641048, 0.6431552586179321, 0.6290485543619702, 0.6359579067373604, 0.6083201458026044, 0.5695983575418089, 0.5759320623400315, 0.5936375303945784, 0.535338980161947, 0.5421045085013443, 0.5177774240016924, 0.5359148034557124, 0.5115877189560603, 0.5173456004605177, 0.535338980161947, 0.5444076259598076, 0.5552036537806653, 0.5726212980466283, 0.5803943853626665]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.5995377898216248], [0.615699291229248], [0.633508026599884], [0.6517550349235535], [0.6705551147460938], [0.6901196837425232], [0.7106518745422363], [0.7322939038276672], [0.7550891637802124], [0.7789819836616516], [0.8038447499275208], [0.8295168280601501], [0.8558377623558044], [0.88266921043396], [0.9098976254463196], [0.9374270439147949], [0.9651651978492737], [0.9930124282836914], [1.0208580493927002], [1.0485820770263672], [1.0760661363601685], [1.1032006740570068], [1.1298933029174805], [1.1560695171356201], [1.1816729307174683], [1.206658124923706], [1.2309883832931519], [1.2546316385269165], [1.2775602340698242], [1.2997506856918335]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[1012.39889773]
#  [1023.62629197]
#  [1035.99801956]
#  [1048.67421535]
#  [1061.73462989]
#  [1075.32613501]
#  [1089.58984696]
#  [1104.62456365]
#  [1120.46042962]
#  [1137.05877043]
#  [1154.33093294]
#  [1172.16532436]
#  [1190.45047613]
#  [1209.0902818 ]
#  [1228.00586038]
#  [1247.13054605]
#  [1266.40024023]
#  [1285.74570986]
#  [1305.09006148]
#  [1324.34994212]
#  [1343.4431168 ]
#  [1362.29347881]
#  [1380.83684678]
#  [1399.02146152]
#  [1416.80815168]
#  [1434.16536488]
#  [1451.06759418]
#  [1467.49256244]
#  [1483.42105664]
#  [1498.8367623 ]]

# %%
from sklearn.preprocessing import MinMaxScaler


sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])
# Out:
# MinMaxScaler()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['close']).set_index(pd.Series(datelist_future))

# Split the data into train, test, and validate
train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a plot
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Platinum Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 297.8875835048976
# Lower Bound of Future Prediction: [[ 714.51131422]
#  [ 725.73870846]
#  [ 738.11043606]
#  [ 750.78663185]
#  [ 763.84704638]
#  [ 777.43855151]
#  [ 791.70226345]
#  [ 806.73698014]
#  [ 822.57284612]
#  [ 839.17118692]
#  [ 856.44334943]
#  [ 874.27774086]
#  [ 892.56289263]
#  [ 911.2026983 ]
#  [ 930.11827688]
#  [ 949.24296254]
#  [ 968.51265673]
#  [ 987.85812635]
#  [1007.20247798]
#  [1026.46235862]
#  [1045.5555333 ]
#  [1064.40589531]
#  [1082.94926328]
#  [1101.13387801]
#  [1118.92056818]
#  [1136.27778137]
#  [1153.18001068]
#  [1169.60497893]
#  [1185.53347314]
#  [1200.94917879]]
# Upper Bound of Future Prediction: [[1310.28648123]
#  [1321.51387547]
#  [1333.88560306]
#  [1346.56179886]
#  [1359.62221339]
#  [1373.21371852]
#  [1387.47743046]
#  [1402.51214715]
#  [1418.34801313]
#  [1434.94635393]
#  [1452.21851644]
#  [1470.05290787]
#  [1488.33805964]
#  [1506.97786531]
#  [1525.89344389]
#  [1545.01812955]
#  [1564.28782374]
#  [1583.63329336]
#  [1602.97764499]
#  [1622.23752563]
#  [1641.33070031]
#  [1660.18106232]
#  [1678.72443029]
#  [1696.90904502]
#  [1714.69573519]
#  [1732.05294838]
#  [1748.95517769]
#  [1765.38014594]
#  [1781.30864015]
#  [1796.7243458 ]]
# Confidence Score: 0.5212047002591855

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  18.208563569802145
# MAPE:  1.872405627548745
# RMSE:  22.474893951214344
#
# ** Validate **
# MAE:  14.898422355938678
# MAPE:  1.6016810263852859
# RMSE:  18.476948773479112

# %%
import pandas as pd

data = {
    "Model": ["LSTM", "LSTM", "LSTM"],
    "Ratio": ["7-2-1", "6-3-1", "5-3-2"],
    "Testing MAE": [14.4476, 17.6834, 20.2988],
    "Testing MAPE": [1.4876, 1.8642, 2.0794],
    "Testing RMSE": [18.1176, 21.7575, 24.8895],
    "Validation MAE": [12.9100, 15.2484, 16.3783],
    "Validation MAPE": [1.3688, 1.6192, 1.7569],
    "Validation RMSE": [16.0406, 19.1244, 20.2222],
}

df = pd.DataFrame(data)

print(df.to_string(index=False))
# Out:
# Model Ratio  Testing MAE  Testing MAPE  Testing RMSE  Validation MAE  Validation MAPE  Validation RMSE
#  LSTM 7-2-1      14.4476        1.4876       18.1176         12.9100           1.3688          16.0406
#  LSTM 6-3-1      17.6834        1.8642       21.7575         15.2484           1.6192          19.1244
#  LSTM 5-3-2      20.2988        2.0794       24.8895         16.3783           1.7569          20.2222
