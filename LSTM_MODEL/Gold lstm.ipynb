# %%
# %pip install numpy pandas matplotlib scikit-learn tensorflow openpyxl
# Out:
# Requirement already satisfied: numpy in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.0.2)
# Requirement already satisfied: pandas in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.2.3)
# Requirement already satisfied: matplotlib in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (3.9.2)
# Requirement already satisfied: scikit-learn in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (1.5.2)
# Requirement already satisfied: tensorflow in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (2.18.0)
# Requirement already satisfied: openpyxl in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from pandas) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.14.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: tensorflow-intel==2.18.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (24.3.25)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.4.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (5.28.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (75.1.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.5.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (4.12.2)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (1.67.1)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.6.0)
# Requirement already satisfied: h5py>=3.11.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (3.12.1)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorflow-intel==2.18.0->tensorflow) (0.4.1)
# Requirement already satisfied: et-xmlfile in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.18.0->tensorflow) (0.44.0)
# Requirement already satisfied: rich in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.0.8)
# Requirement already satisfied: optree in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.13.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from requests<3,>=2.21.0->tensorflow-intel==2.18.0->tensorflow) (2024.8.30)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (3.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow-intel==2.18.0->tensorflow) (2.1.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in c:\users\ken\appdata\local\programs\python\python312\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow-intel==2.18.0->tensorflow) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# %pip install tensorflow --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# Import libraries for data manipulation and analysis
import pandas as pd
import numpy as np

# Import libraries for working with dates and times
import datetime as dt

# Import TensorFlow and Keras libraries for building and training neural networks
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, LSTM, SimpleRNN, Reshape, Flatten
from keras.models import load_model
from keras.callbacks import ModelCheckpoint
from keras.regularizers import l2

# Import scikit-learn library for various metrics and preprocessing tools
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error, r2_score
from sklearn.preprocessing import MinMaxScaler

# Import matplotlib library for creating plots and charts
import matplotlib.pyplot as plt

# Magic command to display plots inline in the Jupyter Notebook
# %matplotlib inline

# %%
# Calculate the accuracy of each model
def evaluateModel(test,pred,val,pred_val):
  print('** Testing **')
  test_mae = mean_absolute_error(test, pred)
  print('MAE: ', test_mae)

  test_ape = np.abs((test - pred) / test)
  test_mape = np.mean(test_ape) * 100
  print('MAPE: ', test_mape)

  test_mse = mean_squared_error(test, pred)
  test_rmse = np.sqrt(test_mse)
  print('RMSE: ', test_rmse)

  print('\n** Validate **')
  val_mae = mean_absolute_error(val, pred_val)
  print('MAE: ', val_mae)

  val_ape = np.abs((val - pred_val) / val)
  val_mape = np.mean(val_ape) * 100
  print('MAPE: ', val_mape)

  val_mse = mean_squared_error(val, pred_val)
  val_rmse = np.sqrt(val_mse)
  print('RMSE: ', val_rmse)

# %%
df = pd.read_excel('Gold_data_filtered.xlsx')
df=df.set_index(pd.DatetimeIndex(df['date'].values))

# %%
    # Format column Date
df.index = pd.to_datetime(df.index,format='%m/%d/%Y')

    # Format column Price to float




    # Create new Dataframe
df1 = pd.DataFrame(df, columns=['date', 'close'])
df1.drop('date', axis = 1, inplace = True)

    # Plot the 'price' column of the 'df' DataFrame
    plt.figure(figsize=(16,5))
    plt.plot(df1['close'])
    plt.title('Prices of Gold')
    plt.show()

# %%
df
# Out:
#                  date         open         high          low        close  \
# 2019-03-01 2019-03-01  1312.199951  1312.199951  1288.900024  1296.400024
# 2019-03-04 2019-03-04  1285.500000  1287.000000  1281.900024  1284.800049
# 2019-03-05 2019-03-05  1287.000000  1287.000000  1282.000000  1282.000000
# 2019-03-06 2019-03-06  1287.099976  1287.099976  1282.599976  1284.900024
# 2019-03-07 2019-03-07  1281.000000  1284.599976  1281.000000  1283.800049
# ...               ...          ...          ...          ...          ...
# 2024-06-17 2024-06-17  2320.199951  2320.199951  2309.600098  2312.399902
# 2024-06-18 2024-06-18  2311.800049  2330.399902  2311.800049  2330.399902
# 2024-06-20 2024-06-20  2328.899902  2354.000000  2328.300049  2353.800049
# 2024-06-21 2024-06-21  2331.199951  2331.199951  2316.399902  2316.399902
# 2024-06-24 2024-06-24  2323.300049  2332.899902  2322.699951  2330.000000
#
#             volume
# 2019-03-01     110
# 2019-03-04      28
# 2019-03-05     114
# 2019-03-06      14
# 2019-03-07      11
# ...            ...
# 2024-06-17     110
# 2024-06-18      43
# 2024-06-20     183
# 2024-06-21      76
# 2024-06-24      76
#
# [1339 rows x 6 columns]

# %%
# Split dataset

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)

# Split the data
train_size = int(0.7 * len(sc_train))
test_size = int(0.2 * len(sc_train))
val_size = len(sc_train) - train_size - test_size

train_data = sc_train[:train_size]
test_data = sc_train[train_size:train_size+test_size]
val_data = sc_train[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an LSTM layer with 50 units
model.add(LSTM(50,return_sequences=True))

# Add an LSTM layer with 50 units
model.add(LSTM(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_7_2_1.keras'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.14605, saving model to save_model_7_2_1.keras
# 17/17 - 3s - 178ms/step - loss: 0.1461
# Epoch 2/80
#
# Epoch 2: loss improved from 0.14605 to 0.04752, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0475
# Epoch 3/80
#
# Epoch 3: loss improved from 0.04752 to 0.03565, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0357
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03565 to 0.03096, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0310
# Epoch 5/80
#
# Epoch 5: loss did not improve from 0.03096
# 17/17 - 1s - 44ms/step - loss: 0.0313
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.03096
# 17/17 - 1s - 44ms/step - loss: 0.0314
# Epoch 7/80
#
# Epoch 7: loss improved from 0.03096 to 0.02978, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0298
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02978
# 17/17 - 1s - 44ms/step - loss: 0.0303
# Epoch 9/80
#
# Epoch 9: loss improved from 0.02978 to 0.02962, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0296
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02962
# 17/17 - 1s - 43ms/step - loss: 0.0298
# Epoch 11/80
#
# Epoch 11: loss improved from 0.02962 to 0.02753, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0275
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02753
# 17/17 - 1s - 43ms/step - loss: 0.0294
# Epoch 13/80
#
# Epoch 13: loss improved from 0.02753 to 0.02651, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0265
# Epoch 14/80
#
# Epoch 14: loss improved from 0.02651 to 0.02466, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0247
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02466
# 17/17 - 1s - 43ms/step - loss: 0.0257
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02466
# 17/17 - 1s - 43ms/step - loss: 0.0247
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02466 to 0.02336, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0234
# Epoch 18/80
#
# Epoch 18: loss improved from 0.02336 to 0.02241, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0224
# Epoch 19/80
#
# Epoch 19: loss improved from 0.02241 to 0.02155, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0216
# Epoch 20/80
#
# Epoch 20: loss did not improve from 0.02155
# 17/17 - 1s - 43ms/step - loss: 0.0229
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.02155
# 17/17 - 1s - 44ms/step - loss: 0.0221
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.02155
# 17/17 - 1s - 43ms/step - loss: 0.0218
# Epoch 23/80
#
# Epoch 23: loss improved from 0.02155 to 0.02101, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0210
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02101 to 0.02016, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0202
# Epoch 25/80
#
# Epoch 25: loss improved from 0.02016 to 0.01989, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0199
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.01989
# 17/17 - 1s - 44ms/step - loss: 0.0200
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.01989
# 17/17 - 1s - 44ms/step - loss: 0.0220
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.01989
# 17/17 - 1s - 44ms/step - loss: 0.0210
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.01989
# 17/17 - 1s - 44ms/step - loss: 0.0216
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.01989
# 17/17 - 1s - 43ms/step - loss: 0.0218
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.01989
# 17/17 - 1s - 43ms/step - loss: 0.0202
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.01989
# 17/17 - 1s - 43ms/step - loss: 0.0202
# Epoch 33/80
#
# Epoch 33: loss improved from 0.01989 to 0.01914, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0191
# Epoch 34/80
#
# Epoch 34: loss improved from 0.01914 to 0.01904, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0190
# Epoch 35/80
#
# Epoch 35: loss improved from 0.01904 to 0.01877, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0188
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01877
# 17/17 - 1s - 43ms/step - loss: 0.0195
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01877
# 17/17 - 1s - 44ms/step - loss: 0.0222
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01877
# 17/17 - 1s - 44ms/step - loss: 0.0221
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01877
# 17/17 - 1s - 43ms/step - loss: 0.0213
# Epoch 40/80
#
# Epoch 40: loss improved from 0.01877 to 0.01860, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0186
# Epoch 41/80
#
# Epoch 41: loss improved from 0.01860 to 0.01817, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0182
# Epoch 42/80
#
# Epoch 42: loss improved from 0.01817 to 0.01746, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0175
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01746
# 17/17 - 1s - 44ms/step - loss: 0.0179
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01746
# 17/17 - 1s - 43ms/step - loss: 0.0184
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01746
# 17/17 - 1s - 44ms/step - loss: 0.0177
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01746
# 17/17 - 1s - 44ms/step - loss: 0.0187
# Epoch 47/80
#
# Epoch 47: loss improved from 0.01746 to 0.01673, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0167
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01673
# 17/17 - 1s - 44ms/step - loss: 0.0168
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01673
# 17/17 - 1s - 43ms/step - loss: 0.0202
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01673
# 17/17 - 1s - 43ms/step - loss: 0.0174
# Epoch 51/80
#
# Epoch 51: loss improved from 0.01673 to 0.01582, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 44ms/step - loss: 0.0158
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01582
# 17/17 - 1s - 44ms/step - loss: 0.0169
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01582
# 17/17 - 1s - 44ms/step - loss: 0.0170
# Epoch 54/80
#
# Epoch 54: loss improved from 0.01582 to 0.01569, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0157
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01569
# 17/17 - 1s - 44ms/step - loss: 0.0180
# Epoch 56/80
#
# Epoch 56: loss improved from 0.01569 to 0.01545, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0154
# Epoch 57/80
#
# Epoch 57: loss improved from 0.01545 to 0.01428, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0143
# Epoch 58/80
#
# Epoch 58: loss did not improve from 0.01428
# 17/17 - 1s - 44ms/step - loss: 0.0154
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01428
# 17/17 - 1s - 44ms/step - loss: 0.0146
# Epoch 60/80
#
# Epoch 60: loss improved from 0.01428 to 0.01393, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0139
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0146
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0145
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0168
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0206
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0144
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01393
# 17/17 - 1s - 44ms/step - loss: 0.0141
# Epoch 67/80
#
# Epoch 67: loss improved from 0.01393 to 0.01344, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0134
# Epoch 68/80
#
# Epoch 68: loss improved from 0.01344 to 0.01268, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0127
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01268
# 17/17 - 1s - 44ms/step - loss: 0.0131
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01268
# 17/17 - 1s - 44ms/step - loss: 0.0154
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01268
# 17/17 - 1s - 44ms/step - loss: 0.0135
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01268
# 17/17 - 1s - 45ms/step - loss: 0.0132
# Epoch 73/80
#
# Epoch 73: loss improved from 0.01268 to 0.01256, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0126
# Epoch 74/80
#
# Epoch 74: loss improved from 0.01256 to 0.01247, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 45ms/step - loss: 0.0125
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01247
# 17/17 - 1s - 44ms/step - loss: 0.0127
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01247
# 17/17 - 1s - 44ms/step - loss: 0.0136
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01247
# 17/17 - 1s - 44ms/step - loss: 0.0142
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01247
# 17/17 - 1s - 44ms/step - loss: 0.0153
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01247
# 17/17 - 1s - 44ms/step - loss: 0.0135
# Epoch 80/80
#
# Epoch 80: loss improved from 0.01247 to 0.01227, saving model to save_model_7_2_1.keras
# 17/17 - 1s - 46ms/step - loss: 0.0123

# %%
from keras.models import load_model

# Reshape y_train to 2D if it's 1D, as MinMaxScaler expects 2D input
y_train = y_train.reshape(-1, 1)

# Transform the y_train array back to the original scale
y_train_original = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_7_2_1.keras')  # Đảm bảo đuôi đúng như đã lưu

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict_original = sc.inverse_transform(y_train_predict)

# Kiểm tra kết quả
print(f"Original y_train shape: {y_train_original.shape}")
print(f"Predicted y_train shape: {y_train_predict_original.shape}")
# Out:
# 27/27 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step
# Original y_train shape: (837, 1)
# Predicted y_train shape: (837, 1)

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.6689850176124654, 0.6729349559903242, 0.6584235129714655, 0.6494933861277543, 0.6570496714918301, 0.6576506943837377, 0.6550747023029009, 0.6474326763169937, 0.6430534059256623, 0.6213292689343695, 0.6190967634277884, 0.6292289360553147, 0.6373003988720811, 0.6510390233032108, 0.6465740122900481, 0.6443414019660807, 0.6605701730388296, 0.6518976873301565, 0.6566203394783574, 0.6557616754514117, 0.6666666666666667, 0.7020435826498714, 0.728490476606751, 0.7420574101594462, 0.7564830077390869, 0.7630946788196136, 0.7807832416286022, 0.7841319474797812, 0.7651553886303744, 0.7780353490345584, 0.7673879989543417, 0.7624936559277062, 0.7654130297654125, 0.7616349919007606, 0.7630087285630103, 0.7840459972231777, 0.7631806290762171, 0.7775202763992544, 0.7782072495477654, 0.7910872099519497, 0.8140992381662744, 0.8304998049348444, 0.8515370735950121, 0.8802163682410866, 0.8754079754710546, 0.907092594211439, 0.9122445783731126, 0.9223768558180254, 0.9104415096973899, 0.9320798012494651, 0.9332818470332802, 0.9415251055458669, 0.9629917062195072, 0.946591139450937, 0.9556930619904696, 0.9695174270434308, 0.9126739103865853, 0.9088099222653301, 0.9060622393060587, 0.9106132005758247, 0.9149065207105529, 0.9240082336153133, 0.8776403761602498, 0.8849390203892875, 0.88433799749738, 0.8841663066189454, 0.9035721974818252, 0.8980766219285099, 0.8967028852662602, 0.912588169764754, 0.9428131015862855, 0.9160228258725367, 0.9308775458308778, 0.9611884279090128, 0.9537180928015403, 0.9813670325422346, 0.9999999999999998, 0.9895243407982177, 0.9616177599224855, 0.9150782115889877, 0.9129315515216236, 0.9324231830063343, 0.9196291728587538, 0.9218615735479492, 0.9046882930090367, 0.9250387981554657, 0.9069209033330041, 0.9314787783575575, 0.9453890936671223, 0.8894899816590538, 0.8916366417264179, 0.891464950847983, 0.9159368756159332, 0.8851966615243256, 0.9119869372380742, 0.8956723207261077, 0.9111282732111288, 0.9312211372225196, 0.8991069768338902, 0.9107848914542596]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.8722073435783386], [0.8289996981620789], [0.7949559092521667], [0.7723333835601807], [0.7551922798156738], [0.7388045787811279], [0.7211547493934631], [0.7023505568504333], [0.6834304928779602], [0.665433406829834], [0.6489718556404114], [0.6342058181762695], [0.6210055351257324], [0.6091318726539612], [0.5983553528785706], [0.5885044932365417], [0.5794646143913269], [0.5711563229560852], [0.5635128021240234], [0.556464433670044], [0.5499340891838074], [0.5438388586044312], [0.538096010684967], [0.5326281189918518], [0.5273672938346863], [0.5222575664520264], [0.5172551274299622], [0.5123274922370911], [0.507452130317688], [0.5026145577430725]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[2285.07259339]
#  [2234.75297587]
#  [2195.10558429]
#  [2168.75939419]
#  [2148.79686728]
#  [2129.71175305]
#  [2109.15676433]
#  [2087.25740445]
#  [2065.22310072]
#  [2044.26369695]
#  [2025.09257684]
#  [2007.89605177]
#  [1992.52300407]
#  [1978.69493849]
#  [1966.14460514]
#  [1954.67229544]
#  [1944.14445387]
#  [1934.46861888]
#  [1925.56697564]
#  [1917.35844677]
#  [1909.75320853]
#  [1902.65470389]
#  [1895.96658405]
#  [1889.59867818]
#  [1883.47192198]
#  [1877.52113422]
#  [1871.69529446]
#  [1865.95657124]
#  [1860.27872546]
#  [1854.64488915]]

# %%
from sklearn.preprocessing import MinMaxScaler

# Khởi tạo MinMaxScaler và huấn luyện với dữ liệu ban đầu
sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])  # Thay 'close' bằng tên cột chứa giá trị cần chuẩn hóa trong dữ liệu của bạn
# Out:
# MinMaxScaler()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Create a dataframe for the future predictions, with the date as the index and the 'price' column
PREDICTIONS_FUTURE = pd.DataFrame(y_pred_future, columns=['close']).set_index(pd.Series(datelist_future))

# Split the data into train, test, and validate
train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# Set the figure size and create a plot
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 178.07480629187629
# Lower Bound of Future Prediction: [[2099.47112729]
#  [2061.96617757]
#  [2026.58194264]
#  [1997.10733205]
#  [1973.34909288]
#  [1954.0977978 ]
#  [1937.8027032 ]
#  [1923.14609349]
#  [1909.27436553]
#  [1895.80635847]
#  [1882.72020641]
#  [1870.19874993]
#  [1858.48695655]
#  [1847.7910599 ]
#  [1838.22642864]
#  [1829.80673763]
#  [1822.46097476]
#  [1816.06086008]
#  [1810.45138863]
#  [1805.47533417]
#  [1800.98914532]
#  [1796.87127544]
#  [1793.02475098]
#  [1789.37425606]
#  [1785.86307818]
#  [1782.44824909]
#  [1779.09714349]
#  [1775.78546593]
#  [1772.49412712]
#  [1769.21056286]]
# Upper Bound of Future Prediction: [[2455.62073987]
#  [2418.11579015]
#  [2382.73155523]
#  [2353.25694464]
#  [2329.49870546]
#  [2310.24741038]
#  [2293.95231578]
#  [2279.29570608]
#  [2265.42397812]
#  [2251.95597105]
#  [2238.86981899]
#  [2226.34836251]
#  [2214.63656913]
#  [2203.94067248]
#  [2194.37604122]
#  [2185.95635021]
#  [2178.61058735]
#  [2172.21047266]
#  [2166.60100121]
#  [2161.62494675]
#  [2157.1387579 ]
#  [2153.02088802]
#  [2149.17436356]
#  [2145.52386865]
#  [2142.01269076]
#  [2138.59786168]
#  [2135.24675607]
#  [2131.93507851]
#  [2128.6437397 ]
#  [2125.36017544]]
# Confidence Score: 0.8258371352770204

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  13.966239100538314
# MAPE:  0.7250050776095164
# RMSE:  18.32821993920444
#
# ** Validate **
# MAE:  36.0939019097222
# MAPE:  1.6041548862076644
# RMSE:  44.192411405856745

# %%
# Split dataset 6-3-1

# %%
#  Split data (6-3-1)
train_size = int(0.6 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
from keras.models import Sequential
from keras.layers import LSTM, Dense
from keras.callbacks import ModelCheckpoint
import numpy as np


x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))  

# Build the model
model = Sequential()

# Add LSTM layers
model.add(LSTM(50, return_sequences=True, input_shape=(x_train.shape[1], 1)))
model.add(LSTM(50, return_sequences=True))
model.add(LSTM(50))

# Add Dense output layer
model.add(Dense(1))

# Compile the model
model.compile(loss='mean_absolute_error', optimizer='adam')

# Set the filename to use for saving the best model
save_model = 'save_model_6_3_1.keras'

# Create a ModelCheckpoint callback to save the best model based on 'loss'
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.13271, saving model to save_model_6_3_1.keras
# 15/15 - 3s - 188ms/step - loss: 0.1327
# Epoch 2/80
#
# Epoch 2: loss improved from 0.13271 to 0.03866, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0387
# Epoch 3/80
#
# Epoch 3: loss improved from 0.03866 to 0.03411, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0341
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03411 to 0.03187, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0319
# Epoch 5/80
#
# Epoch 5: loss did not improve from 0.03187
# 15/15 - 1s - 43ms/step - loss: 0.0321
# Epoch 6/80
#
# Epoch 6: loss improved from 0.03187 to 0.02904, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0290
# Epoch 7/80
#
# Epoch 7: loss improved from 0.02904 to 0.02806, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0281
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02806
# 15/15 - 1s - 45ms/step - loss: 0.0320
# Epoch 9/80
#
# Epoch 9: loss improved from 0.02806 to 0.02724, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 46ms/step - loss: 0.0272
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02724
# 15/15 - 1s - 45ms/step - loss: 0.0291
# Epoch 11/80
#
# Epoch 11: loss improved from 0.02724 to 0.02706, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0271
# Epoch 12/80
#
# Epoch 12: loss improved from 0.02706 to 0.02505, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 46ms/step - loss: 0.0250
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02505
# 15/15 - 1s - 43ms/step - loss: 0.0285
# Epoch 14/80
#
# Epoch 14: loss improved from 0.02505 to 0.02462, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0246
# Epoch 15/80
#
# Epoch 15: loss improved from 0.02462 to 0.02437, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 46ms/step - loss: 0.0244
# Epoch 16/80
#
# Epoch 16: loss did not improve from 0.02437
# 15/15 - 1s - 43ms/step - loss: 0.0244
# Epoch 17/80
#
# Epoch 17: loss did not improve from 0.02437
# 15/15 - 1s - 43ms/step - loss: 0.0262
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02437
# 15/15 - 1s - 43ms/step - loss: 0.0283
# Epoch 19/80
#
# Epoch 19: loss improved from 0.02437 to 0.02232, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0223
# Epoch 20/80
#
# Epoch 20: loss improved from 0.02232 to 0.02205, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0221
# Epoch 21/80
#
# Epoch 21: loss did not improve from 0.02205
# 15/15 - 1s - 45ms/step - loss: 0.0240
# Epoch 22/80
#
# Epoch 22: loss improved from 0.02205 to 0.02178, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0218
# Epoch 23/80
#
# Epoch 23: loss did not improve from 0.02178
# 15/15 - 1s - 43ms/step - loss: 0.0271
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02178 to 0.02092, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0209
# Epoch 25/80
#
# Epoch 25: loss did not improve from 0.02092
# 15/15 - 1s - 44ms/step - loss: 0.0218
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02092
# 15/15 - 1s - 43ms/step - loss: 0.0212
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02092
# 15/15 - 1s - 43ms/step - loss: 0.0211
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02092
# 15/15 - 1s - 45ms/step - loss: 0.0211
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02092
# 15/15 - 1s - 43ms/step - loss: 0.0213
# Epoch 30/80
#
# Epoch 30: loss improved from 0.02092 to 0.02034, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0203
# Epoch 31/80
#
# Epoch 31: loss improved from 0.02034 to 0.02005, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0200
# Epoch 32/80
#
# Epoch 32: loss did not improve from 0.02005
# 15/15 - 1s - 43ms/step - loss: 0.0264
# Epoch 33/80
#
# Epoch 33: loss did not improve from 0.02005
# 15/15 - 1s - 43ms/step - loss: 0.0217
# Epoch 34/80
#
# Epoch 34: loss did not improve from 0.02005
# 15/15 - 1s - 43ms/step - loss: 0.0202
# Epoch 35/80
#
# Epoch 35: loss did not improve from 0.02005
# 15/15 - 1s - 45ms/step - loss: 0.0220
# Epoch 36/80
#
# Epoch 36: loss improved from 0.02005 to 0.01925, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0192
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01925
# 15/15 - 1s - 42ms/step - loss: 0.0249
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01925
# 15/15 - 1s - 43ms/step - loss: 0.0214
# Epoch 39/80
#
# Epoch 39: loss improved from 0.01925 to 0.01895, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 44ms/step - loss: 0.0190
# Epoch 40/80
#
# Epoch 40: loss did not improve from 0.01895
# 15/15 - 1s - 43ms/step - loss: 0.0193
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01895
# 15/15 - 1s - 42ms/step - loss: 0.0215
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01895
# 15/15 - 1s - 43ms/step - loss: 0.0200
# Epoch 43/80
#
# Epoch 43: loss improved from 0.01895 to 0.01862, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0186
# Epoch 44/80
#
# Epoch 44: loss did not improve from 0.01862
# 15/15 - 1s - 43ms/step - loss: 0.0201
# Epoch 45/80
#
# Epoch 45: loss did not improve from 0.01862
# 15/15 - 1s - 43ms/step - loss: 0.0193
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01862
# 15/15 - 1s - 44ms/step - loss: 0.0214
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01862
# 15/15 - 1s - 43ms/step - loss: 0.0189
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01862
# 15/15 - 1s - 42ms/step - loss: 0.0200
# Epoch 49/80
#
# Epoch 49: loss did not improve from 0.01862
# 15/15 - 1s - 43ms/step - loss: 0.0193
# Epoch 50/80
#
# Epoch 50: loss improved from 0.01862 to 0.01802, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0180
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01802
# 15/15 - 1s - 43ms/step - loss: 0.0184
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01802
# 15/15 - 1s - 43ms/step - loss: 0.0183
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01802
# 15/15 - 1s - 42ms/step - loss: 0.0247
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01802
# 15/15 - 1s - 43ms/step - loss: 0.0238
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01802
# 15/15 - 1s - 43ms/step - loss: 0.0186
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01802
# 15/15 - 1s - 43ms/step - loss: 0.0185
# Epoch 57/80
#
# Epoch 57: loss did not improve from 0.01802
# 15/15 - 1s - 44ms/step - loss: 0.0208
# Epoch 58/80
#
# Epoch 58: loss improved from 0.01802 to 0.01728, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0173
# Epoch 59/80
#
# Epoch 59: loss did not improve from 0.01728
# 15/15 - 1s - 43ms/step - loss: 0.0181
# Epoch 60/80
#
# Epoch 60: loss did not improve from 0.01728
# 15/15 - 1s - 42ms/step - loss: 0.0191
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01728
# 15/15 - 1s - 43ms/step - loss: 0.0191
# Epoch 62/80
#
# Epoch 62: loss did not improve from 0.01728
# 15/15 - 1s - 43ms/step - loss: 0.0233
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01728
# 15/15 - 1s - 43ms/step - loss: 0.0180
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01728
# 15/15 - 1s - 47ms/step - loss: 0.0192
# Epoch 65/80
#
# Epoch 65: loss improved from 0.01728 to 0.01629, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 48ms/step - loss: 0.0163
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01629
# 15/15 - 1s - 48ms/step - loss: 0.0166
# Epoch 67/80
#
# Epoch 67: loss improved from 0.01629 to 0.01552, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 47ms/step - loss: 0.0155
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01552
# 15/15 - 1s - 43ms/step - loss: 0.0155
# Epoch 69/80
#
# Epoch 69: loss did not improve from 0.01552
# 15/15 - 1s - 43ms/step - loss: 0.0158
# Epoch 70/80
#
# Epoch 70: loss did not improve from 0.01552
# 15/15 - 1s - 44ms/step - loss: 0.0164
# Epoch 71/80
#
# Epoch 71: loss improved from 0.01552 to 0.01474, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 46ms/step - loss: 0.0147
# Epoch 72/80
#
# Epoch 72: loss improved from 0.01474 to 0.01442, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 46ms/step - loss: 0.0144
# Epoch 73/80
#
# Epoch 73: loss did not improve from 0.01442
# 15/15 - 1s - 45ms/step - loss: 0.0148
# Epoch 74/80
#
# Epoch 74: loss improved from 0.01442 to 0.01418, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0142
# Epoch 75/80
#
# Epoch 75: loss improved from 0.01418 to 0.01379, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 45ms/step - loss: 0.0138
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01379
# 15/15 - 1s - 44ms/step - loss: 0.0153
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01379
# 15/15 - 1s - 45ms/step - loss: 0.0139
# Epoch 78/80
#
# Epoch 78: loss improved from 0.01379 to 0.01332, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 47ms/step - loss: 0.0133
# Epoch 79/80
#
# Epoch 79: loss improved from 0.01332 to 0.01303, saving model to save_model_6_3_1.keras
# 15/15 - 1s - 48ms/step - loss: 0.0130
# Epoch 80/80
#
# Epoch 80: loss did not improve from 0.01303
# 15/15 - 1s - 44ms/step - loss: 0.0139

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_6_3_1.keras')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 11/13 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but MinMaxScaler was fitted with feature names
#   warnings.warn(

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.6689850176124654, 0.6729349559903242, 0.6584235129714655, 0.6494933861277543, 0.6570496714918301, 0.6576506943837377, 0.6550747023029009, 0.6474326763169937, 0.6430534059256623, 0.6213292689343695, 0.6190967634277884, 0.6292289360553147, 0.6373003988720811, 0.6510390233032108, 0.6465740122900481, 0.6443414019660807, 0.6605701730388296, 0.6518976873301565, 0.6566203394783574, 0.6557616754514117, 0.6666666666666667, 0.7020435826498714, 0.728490476606751, 0.7420574101594462, 0.7564830077390869, 0.7630946788196136, 0.7807832416286022, 0.7841319474797812, 0.7651553886303744, 0.7780353490345584, 0.7673879989543417, 0.7624936559277062, 0.7654130297654125, 0.7616349919007606, 0.7630087285630103, 0.7840459972231777, 0.7631806290762171, 0.7775202763992544, 0.7782072495477654, 0.7910872099519497, 0.8140992381662744, 0.8304998049348444, 0.8515370735950121, 0.8802163682410866, 0.8754079754710546, 0.907092594211439, 0.9122445783731126, 0.9223768558180254, 0.9104415096973899, 0.9320798012494651, 0.9332818470332802, 0.9415251055458669, 0.9629917062195072, 0.946591139450937, 0.9556930619904696, 0.9695174270434308, 0.9126739103865853, 0.9088099222653301, 0.9060622393060587, 0.9106132005758247, 0.9149065207105529, 0.9240082336153133, 0.8776403761602498, 0.8849390203892875, 0.88433799749738, 0.8841663066189454, 0.9035721974818252, 0.8980766219285099, 0.8967028852662602, 0.912588169764754, 0.9428131015862855, 0.9160228258725367, 0.9308775458308778, 0.9611884279090128, 0.9537180928015403, 0.9813670325422346, 0.9999999999999998, 0.9895243407982177, 0.9616177599224855, 0.9150782115889877, 0.9129315515216236, 0.9324231830063343, 0.9196291728587538, 0.9218615735479492, 0.9046882930090367, 0.9250387981554657, 0.9069209033330041, 0.9314787783575575, 0.9453890936671223, 0.8894899816590538, 0.8916366417264179, 0.891464950847983, 0.9159368756159332, 0.8851966615243256, 0.9119869372380742, 0.8956723207261077, 0.9111282732111288, 0.9312211372225196, 0.8991069768338902, 0.9107848914542596]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.9162536263465881], [0.9286845922470093], [0.9408358335494995], [0.9514559507369995], [0.959717869758606], [0.9658910036087036], [0.9707533717155457], [0.9750645160675049], [0.979263424873352], [0.983414351940155], [0.9873253107070923], [0.9907311797142029], [0.9934386014938354], [0.9953938722610474], [0.9966749548912048], [0.9974376559257507], [0.9978539347648621], [0.998067319393158], [0.9981757402420044], [0.9982367753982544], [0.9982830882072449], [0.9983381628990173], [0.9984259009361267], [0.9985719323158264], [0.9988002181053162], [0.9991278052330017], [0.9995617270469666], [1.0000983476638794], [1.000725269317627], [1.0014241933822632]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[2336.36888785]
#  [2350.84598892]
#  [2364.99732276]
#  [2377.36550968]
#  [2386.98733937]
#  [2394.17657014]
#  [2399.83928333]
#  [2404.86004141]
#  [2409.75008999]
#  [2414.58425904]
#  [2419.13896105]
#  [2423.1054356 ]
#  [2426.2584986 ]
#  [2428.53560665]
#  [2430.0275553 ]
#  [2430.91579681]
#  [2431.40059509]
#  [2431.64910279]
#  [2431.7753697 ]
#  [2431.84645123]
#  [2431.90038712]
#  [2431.9645271 ]
#  [2432.0667068 ]
#  [2432.23677493]
#  [2432.50263652]
#  [2432.88414445]
#  [2433.38948973]
#  [2434.01443802]
#  [2434.74455088]
#  [2435.55851775]]

# %%
from sklearn.preprocessing import MinMaxScaler


sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])
# Out:
# MinMaxScaler()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 178.07480629187629
# Lower Bound of Future Prediction: [[2099.47112729]
#  [2061.96617757]
#  [2026.58194264]
#  [1997.10733205]
#  [1973.34909288]
#  [1954.0977978 ]
#  [1937.8027032 ]
#  [1923.14609349]
#  [1909.27436553]
#  [1895.80635847]
#  [1882.72020641]
#  [1870.19874993]
#  [1858.48695655]
#  [1847.7910599 ]
#  [1838.22642864]
#  [1829.80673763]
#  [1822.46097476]
#  [1816.06086008]
#  [1810.45138863]
#  [1805.47533417]
#  [1800.98914532]
#  [1796.87127544]
#  [1793.02475098]
#  [1789.37425606]
#  [1785.86307818]
#  [1782.44824909]
#  [1779.09714349]
#  [1775.78546593]
#  [1772.49412712]
#  [1769.21056286]]
# Upper Bound of Future Prediction: [[2455.62073987]
#  [2418.11579015]
#  [2382.73155523]
#  [2353.25694464]
#  [2329.49870546]
#  [2310.24741038]
#  [2293.95231578]
#  [2279.29570608]
#  [2265.42397812]
#  [2251.95597105]
#  [2238.86981899]
#  [2226.34836251]
#  [2214.63656913]
#  [2203.94067248]
#  [2194.37604122]
#  [2185.95635021]
#  [2178.61058735]
#  [2172.21047266]
#  [2166.60100121]
#  [2161.62494675]
#  [2157.1387579 ]
#  [2153.02088802]
#  [2149.17436356]
#  [2145.52386865]
#  [2142.01269076]
#  [2138.59786168]
#  [2135.24675607]
#  [2131.93507851]
#  [2128.6437397 ]
#  [2125.36017544]]
# Confidence Score: 0.8258371352770204

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  13.395991223114113
# MAPE:  0.7257089257756679
# RMSE:  17.418716504586634
#
# ** Validate **
# MAE:  22.821632667824073
# MAPE:  1.0181584528710093
# RMSE:  28.561803306063183

# %%
# Split dataset 5-3-2

# %%
# Create a MinMaxScaler object with a specified range
data = df1.values
sc = MinMaxScaler(feature_range=(0, 1))

# Fit the scaler to the data and transform the data
sc_train = sc.fit_transform(data)# Split data



train_size = int(0.5 * len(df1))
test_size = int(0.3 * len(df1))
val_size = len(df1) - train_size - test_size

train_data = df1[:train_size]
test_data = df1[train_size:train_size+test_size]
val_data = df1[train_size+test_size:]

# %%
# Create training datasets for the model
x_train, y_train = [], []

# Loop through the train data, starting from the 5th value
for i in range(100, len(train_data)):
    # Append the last 100 values to the x_train array
    x_train.append(sc_train[i-100:i, 0])
    # Append the current value to the y_train array
    y_train.append(sc_train[i, 0])

# %%
# Convert the x_train and y_train arrays to NumPy arrays
x_train = np.array(x_train)
y_train = np.array(y_train)

# Reshape the x_train and y_train arrays to be one-dimensional
x_train = np.reshape(x_train, (x_train.shape[0], x_train.shape[1], 1))
y_train = np.reshape(y_train, (y_train.shape[0], 1))

# %%
# Build the model
model = Sequential()

# Add an LSTM layer with 50 units, input shape of (x_train.shape[1], 1), and return_sequences set to True
model.add(LSTM(50,return_sequences=True,input_shape=(x_train.shape[1],1)))

# Add an LSTM layer with 50 units
model.add(LSTM(50,return_sequences=True))

# Add an LSTM layer with 50 units
model.add(LSTM(50))

# Add a dense layer with 1 unit
model.add(Dense(1))

# Compile the model with the 'mean_absolute_error' loss function and the 'adam' optimizer
model.compile(loss='mean_absolute_error', optimizer='adam')
# Set the filename to use for saving the model
save_model = 'save_model_5_3_2.keras'

# Create a ModelCheckpoint object to save the model during training
best_model = ModelCheckpoint(save_model, monitor='loss', verbose=2, save_best_only=True, mode='auto')

# Train the model using the 'fit' method
model.fit(x_train, y_train, epochs=80, batch_size=50, verbose=2, callbacks=[best_model])
# Out:
# Epoch 1/80
# c:\Users\Ken\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\rnn\rnn.py:204: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Epoch 1: loss improved from inf to 0.18093, saving model to save_model_5_3_2.keras
# 12/12 - 3s - 229ms/step - loss: 0.1809
# Epoch 2/80
#
# Epoch 2: loss improved from 0.18093 to 0.05785, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0578
# Epoch 3/80
#
# Epoch 3: loss improved from 0.05785 to 0.03896, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0390
# Epoch 4/80
#
# Epoch 4: loss improved from 0.03896 to 0.03151, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 50ms/step - loss: 0.0315
# Epoch 5/80
#
# Epoch 5: loss improved from 0.03151 to 0.03028, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 51ms/step - loss: 0.0303
# Epoch 6/80
#
# Epoch 6: loss did not improve from 0.03028
# 12/12 - 1s - 46ms/step - loss: 0.0321
# Epoch 7/80
#
# Epoch 7: loss improved from 0.03028 to 0.02978, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 48ms/step - loss: 0.0298
# Epoch 8/80
#
# Epoch 8: loss did not improve from 0.02978
# 12/12 - 1s - 47ms/step - loss: 0.0304
# Epoch 9/80
#
# Epoch 9: loss improved from 0.02978 to 0.02929, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 50ms/step - loss: 0.0293
# Epoch 10/80
#
# Epoch 10: loss did not improve from 0.02929
# 12/12 - 1s - 47ms/step - loss: 0.0293
# Epoch 11/80
#
# Epoch 11: loss improved from 0.02929 to 0.02796, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 48ms/step - loss: 0.0280
# Epoch 12/80
#
# Epoch 12: loss did not improve from 0.02796
# 12/12 - 1s - 46ms/step - loss: 0.0288
# Epoch 13/80
#
# Epoch 13: loss did not improve from 0.02796
# 12/12 - 1s - 47ms/step - loss: 0.0287
# Epoch 14/80
#
# Epoch 14: loss did not improve from 0.02796
# 12/12 - 1s - 46ms/step - loss: 0.0291
# Epoch 15/80
#
# Epoch 15: loss did not improve from 0.02796
# 12/12 - 1s - 44ms/step - loss: 0.0282
# Epoch 16/80
#
# Epoch 16: loss improved from 0.02796 to 0.02534, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0253
# Epoch 17/80
#
# Epoch 17: loss improved from 0.02534 to 0.02451, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 49ms/step - loss: 0.0245
# Epoch 18/80
#
# Epoch 18: loss did not improve from 0.02451
# 12/12 - 1s - 44ms/step - loss: 0.0259
# Epoch 19/80
#
# Epoch 19: loss improved from 0.02451 to 0.02436, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0244
# Epoch 20/80
#
# Epoch 20: loss improved from 0.02436 to 0.02305, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0230
# Epoch 21/80
#
# Epoch 21: loss improved from 0.02305 to 0.02282, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0228
# Epoch 22/80
#
# Epoch 22: loss did not improve from 0.02282
# 12/12 - 1s - 44ms/step - loss: 0.0236
# Epoch 23/80
#
# Epoch 23: loss improved from 0.02282 to 0.02264, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0226
# Epoch 24/80
#
# Epoch 24: loss improved from 0.02264 to 0.02112, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0211
# Epoch 25/80
#
# Epoch 25: loss improved from 0.02112 to 0.02084, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0208
# Epoch 26/80
#
# Epoch 26: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0215
# Epoch 27/80
#
# Epoch 27: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0237
# Epoch 28/80
#
# Epoch 28: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0222
# Epoch 29/80
#
# Epoch 29: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0227
# Epoch 30/80
#
# Epoch 30: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0212
# Epoch 31/80
#
# Epoch 31: loss did not improve from 0.02084
# 12/12 - 1s - 44ms/step - loss: 0.0211
# Epoch 32/80
#
# Epoch 32: loss improved from 0.02084 to 0.02067, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0207
# Epoch 33/80
#
# Epoch 33: loss improved from 0.02067 to 0.02055, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0206
# Epoch 34/80
#
# Epoch 34: loss improved from 0.02055 to 0.01997, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0200
# Epoch 35/80
#
# Epoch 35: loss improved from 0.01997 to 0.01966, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0197
# Epoch 36/80
#
# Epoch 36: loss did not improve from 0.01966
# 12/12 - 1s - 43ms/step - loss: 0.0200
# Epoch 37/80
#
# Epoch 37: loss did not improve from 0.01966
# 12/12 - 1s - 44ms/step - loss: 0.0204
# Epoch 38/80
#
# Epoch 38: loss did not improve from 0.01966
# 12/12 - 1s - 43ms/step - loss: 0.0199
# Epoch 39/80
#
# Epoch 39: loss did not improve from 0.01966
# 12/12 - 1s - 44ms/step - loss: 0.0198
# Epoch 40/80
#
# Epoch 40: loss improved from 0.01966 to 0.01931, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0193
# Epoch 41/80
#
# Epoch 41: loss did not improve from 0.01931
# 12/12 - 1s - 44ms/step - loss: 0.0195
# Epoch 42/80
#
# Epoch 42: loss did not improve from 0.01931
# 12/12 - 1s - 44ms/step - loss: 0.0199
# Epoch 43/80
#
# Epoch 43: loss did not improve from 0.01931
# 12/12 - 1s - 44ms/step - loss: 0.0203
# Epoch 44/80
#
# Epoch 44: loss improved from 0.01931 to 0.01911, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0191
# Epoch 45/80
#
# Epoch 45: loss improved from 0.01911 to 0.01890, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0189
# Epoch 46/80
#
# Epoch 46: loss did not improve from 0.01890
# 12/12 - 1s - 44ms/step - loss: 0.0190
# Epoch 47/80
#
# Epoch 47: loss did not improve from 0.01890
# 12/12 - 1s - 43ms/step - loss: 0.0207
# Epoch 48/80
#
# Epoch 48: loss did not improve from 0.01890
# 12/12 - 1s - 44ms/step - loss: 0.0214
# Epoch 49/80
#
# Epoch 49: loss improved from 0.01890 to 0.01881, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0188
# Epoch 50/80
#
# Epoch 50: loss did not improve from 0.01881
# 12/12 - 1s - 44ms/step - loss: 0.0223
# Epoch 51/80
#
# Epoch 51: loss did not improve from 0.01881
# 12/12 - 1s - 44ms/step - loss: 0.0212
# Epoch 52/80
#
# Epoch 52: loss did not improve from 0.01881
# 12/12 - 1s - 43ms/step - loss: 0.0197
# Epoch 53/80
#
# Epoch 53: loss did not improve from 0.01881
# 12/12 - 1s - 43ms/step - loss: 0.0205
# Epoch 54/80
#
# Epoch 54: loss did not improve from 0.01881
# 12/12 - 1s - 43ms/step - loss: 0.0199
# Epoch 55/80
#
# Epoch 55: loss did not improve from 0.01881
# 12/12 - 1s - 43ms/step - loss: 0.0189
# Epoch 56/80
#
# Epoch 56: loss did not improve from 0.01881
# 12/12 - 1s - 44ms/step - loss: 0.0197
# Epoch 57/80
#
# Epoch 57: loss improved from 0.01881 to 0.01852, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0185
# Epoch 58/80
#
# Epoch 58: loss improved from 0.01852 to 0.01803, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0180
# Epoch 59/80
#
# Epoch 59: loss improved from 0.01803 to 0.01796, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 44ms/step - loss: 0.0180
# Epoch 60/80
#
# Epoch 60: loss improved from 0.01796 to 0.01779, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 45ms/step - loss: 0.0178
# Epoch 61/80
#
# Epoch 61: loss did not improve from 0.01779
# 12/12 - 1s - 44ms/step - loss: 0.0194
# Epoch 62/80
#
# Epoch 62: loss improved from 0.01779 to 0.01711, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0171
# Epoch 63/80
#
# Epoch 63: loss did not improve from 0.01711
# 12/12 - 1s - 44ms/step - loss: 0.0176
# Epoch 64/80
#
# Epoch 64: loss did not improve from 0.01711
# 12/12 - 1s - 44ms/step - loss: 0.0180
# Epoch 65/80
#
# Epoch 65: loss did not improve from 0.01711
# 12/12 - 1s - 43ms/step - loss: 0.0180
# Epoch 66/80
#
# Epoch 66: loss did not improve from 0.01711
# 12/12 - 1s - 43ms/step - loss: 0.0172
# Epoch 67/80
#
# Epoch 67: loss did not improve from 0.01711
# 12/12 - 1s - 45ms/step - loss: 0.0174
# Epoch 68/80
#
# Epoch 68: loss did not improve from 0.01711
# 12/12 - 1s - 44ms/step - loss: 0.0184
# Epoch 69/80
#
# Epoch 69: loss improved from 0.01711 to 0.01690, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0169
# Epoch 70/80
#
# Epoch 70: loss improved from 0.01690 to 0.01615, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0161
# Epoch 71/80
#
# Epoch 71: loss did not improve from 0.01615
# 12/12 - 1s - 45ms/step - loss: 0.0162
# Epoch 72/80
#
# Epoch 72: loss did not improve from 0.01615
# 12/12 - 1s - 44ms/step - loss: 0.0163
# Epoch 73/80
#
# Epoch 73: loss improved from 0.01615 to 0.01554, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0155
# Epoch 74/80
#
# Epoch 74: loss did not improve from 0.01554
# 12/12 - 1s - 45ms/step - loss: 0.0171
# Epoch 75/80
#
# Epoch 75: loss did not improve from 0.01554
# 12/12 - 1s - 46ms/step - loss: 0.0174
# Epoch 76/80
#
# Epoch 76: loss did not improve from 0.01554
# 12/12 - 1s - 45ms/step - loss: 0.0171
# Epoch 77/80
#
# Epoch 77: loss did not improve from 0.01554
# 12/12 - 1s - 44ms/step - loss: 0.0190
# Epoch 78/80
#
# Epoch 78: loss did not improve from 0.01554
# 12/12 - 1s - 48ms/step - loss: 0.0159
# Epoch 79/80
#
# Epoch 79: loss did not improve from 0.01554
# 12/12 - 1s - 44ms/step - loss: 0.0179
# Epoch 80/80
#
# Epoch 80: loss improved from 0.01554 to 0.01445, saving model to save_model_5_3_2.keras
# 12/12 - 1s - 46ms/step - loss: 0.0145

# %%
# Transform the y_train array back to the original scale
y_train = sc.inverse_transform(y_train)

# Load the best model from the save_model.keras file
final_model = load_model('save_model_5_3_2.keras')

# Use the model to make predictions on the x_train data
y_train_predict = final_model.predict(x_train)

# Transform the y_train_predict array back to the original scale
y_train_predict = sc.inverse_transform(y_train_predict)
# Out:
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step

# %%
# Preprocess the test data
test = df1[len(train_data)-100:train_size+test_size].values
test = test.reshape(-1, 1)
sc_test = sc.transform(test)

# Create the x_test array for the test data
x_test = []
for i in range(100, test.shape[0]):
    x_test.append(sc_test[i-100:i, 0])
x_test = np.array(x_test)
x_test = np.reshape(x_test, (x_test.shape[0], x_test.shape[1], 1))

# Get the true values for the test data
y_test = data[train_size:train_size+test_size]  # True values

# Use the model to make predictions on the x_test data
y_test_predict = final_model.predict(x_test)

# Transform the y_test_predict array back to the original scale
y_test_predict = sc.inverse_transform(y_test_predict)  # Predicted values
# Out:
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Preprocess the validate data
val = df1[train_size+test_size-100:].values
val = val.reshape(-1, 1)
sc_val = sc.transform(val)

# Create the x_val array for the validate data
x_val = []
for i in range(100, val.shape[0]):
    x_val.append(sc_val[i-100:i, 0])
x_val = np.array(x_val)
x_val = np.reshape(x_val, (x_val.shape[0], x_val.shape[1], 1))

# Get the true values for the validate data
y_val = data[train_size+test_size:]  # True values

# Use the model to make predictions on the x_val data
y_val_predict = final_model.predict(x_val)

# Transform the y_val_predict array back to the original scale
y_val_predict = sc.inverse_transform(y_val_predict)  # Predicted values
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step

# %%
# Create an input array using the last 10 days of the scaled test data
x_input = sc_train[len(sc_train) - 100:].reshape(1, -1)

# Print the shape of the input array
print(x_input.shape)

# Convert x_input to a list and extract the first element
temp_input = list(x_input)
temp_input = temp_input[0].tolist()

# Print the temp_input variable
print(temp_input)
# Out:
# (1, 100)
# [0.6689850176124654, 0.6729349559903242, 0.6584235129714655, 0.6494933861277543, 0.6570496714918301, 0.6576506943837377, 0.6550747023029009, 0.6474326763169937, 0.6430534059256623, 0.6213292689343695, 0.6190967634277884, 0.6292289360553147, 0.6373003988720811, 0.6510390233032108, 0.6465740122900481, 0.6443414019660807, 0.6605701730388296, 0.6518976873301565, 0.6566203394783574, 0.6557616754514117, 0.6666666666666667, 0.7020435826498714, 0.728490476606751, 0.7420574101594462, 0.7564830077390869, 0.7630946788196136, 0.7807832416286022, 0.7841319474797812, 0.7651553886303744, 0.7780353490345584, 0.7673879989543417, 0.7624936559277062, 0.7654130297654125, 0.7616349919007606, 0.7630087285630103, 0.7840459972231777, 0.7631806290762171, 0.7775202763992544, 0.7782072495477654, 0.7910872099519497, 0.8140992381662744, 0.8304998049348444, 0.8515370735950121, 0.8802163682410866, 0.8754079754710546, 0.907092594211439, 0.9122445783731126, 0.9223768558180254, 0.9104415096973899, 0.9320798012494651, 0.9332818470332802, 0.9415251055458669, 0.9629917062195072, 0.946591139450937, 0.9556930619904696, 0.9695174270434308, 0.9126739103865853, 0.9088099222653301, 0.9060622393060587, 0.9106132005758247, 0.9149065207105529, 0.9240082336153133, 0.8776403761602498, 0.8849390203892875, 0.88433799749738, 0.8841663066189454, 0.9035721974818252, 0.8980766219285099, 0.8967028852662602, 0.912588169764754, 0.9428131015862855, 0.9160228258725367, 0.9308775458308778, 0.9611884279090128, 0.9537180928015403, 0.9813670325422346, 0.9999999999999998, 0.9895243407982177, 0.9616177599224855, 0.9150782115889877, 0.9129315515216236, 0.9324231830063343, 0.9196291728587538, 0.9218615735479492, 0.9046882930090367, 0.9250387981554657, 0.9069209033330041, 0.9314787783575575, 0.9453890936671223, 0.8894899816590538, 0.8916366417264179, 0.891464950847983, 0.9159368756159332, 0.8851966615243256, 0.9119869372380742, 0.8956723207261077, 0.9111282732111288, 0.9312211372225196, 0.8991069768338902, 0.9107848914542596]

# %%
# Initialize variables
lst_output = []
n_steps = 100
i = 0

# Loop through the next 30 days
while(i < 30):
    # If the length of temp_input is greater than 30, use the first 30 elements to make a prediction
    if(len(temp_input) > 100):
        # Extract the first 3 elements of temp_input and reshape them for input to the model
        x_input = np.array(temp_input[1:])
        x_input = x_input.reshape((1, -1))
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list and remove the first element
        temp_input.extend(yhat[0].tolist())
        temp_input = temp_input[1:]

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1
    # If the length of temp_input is less than 30, use the entire list to make a prediction
    else:
        # Reshape temp_input for input to the model
        x_input = x_input.reshape((1, n_steps, 1))

        # Make a prediction using the model
        yhat = model.predict(x_input, verbose=0)

        # Add the prediction to the temp_input list
        temp_input.extend(yhat[0].tolist())

        # Add the prediction to the lst_output list
        lst_output.extend(yhat.tolist())
        i += 1

# Print the final list of predictions
print(lst_output)
# Out:
# [[0.8657444715499878], [0.8335403203964233], [0.8031571507453918], [0.7778483629226685], [0.7574480175971985], [0.7409176230430603], [0.7269256114959717], [0.7143405079841614], [0.7024293541908264], [0.6908648610115051], [0.6796282529830933], [0.6688765287399292], [0.6588200330734253], [0.6496358513832092], [0.6414230465888977], [0.6341933608055115], [0.6278858184814453], [0.6223902702331543], [0.617573618888855], [0.6133008599281311], [0.6094487309455872], [0.6059128642082214], [0.6026099920272827], [0.5994754433631897], [0.5964605212211609], [0.5935283303260803], [0.5906508564949036], [0.5878072381019592], [0.5849810838699341], [0.5821616053581238]]

# %%
# Convert the 'date' column in the dataframe to a list of strings
datelist_train = df['date'].astype(str).tolist()


# Parse the date strings using strptime(), using the correct format string
datelist_train = [dt.datetime.strptime(date, '%Y-%m-%d').date() for date in datelist_train]


# Generate a list of future dates, starting from the last date in the training data and going for 15 days
datelist_future = pd.date_range(datelist_train[-1], periods=30, freq='1d').tolist()

# %%
# Inverse transform the lst_output list using the StandardScaler object
y_pred_future = sc.inverse_transform(lst_output)

# Print the inverse transformed list of predictions
print(y_pred_future)
# Out:
# [[2277.54593358]
#  [2240.04098386]
#  [2204.65674894]
#  [2175.18213835]
#  [2151.42389917]
#  [2132.17260409]
#  [2115.87750949]
#  [2101.22089979]
#  [2087.34917182]
#  [2073.88116476]
#  [2060.7950127 ]
#  [2048.27355622]
#  [2036.56176284]
#  [2025.86586619]
#  [2016.30123493]
#  [2007.88154392]
#  [2000.53578106]
#  [1994.13566637]
#  [1988.52619492]
#  [1983.55014046]
#  [1979.06395161]
#  [1974.94608173]
#  [1971.09955727]
#  [1967.44906236]
#  [1963.93788447]
#  [1960.52305538]
#  [1957.17194978]
#  [1953.86027222]
#  [1950.56893341]
#  [1947.28536915]]

# %%
from sklearn.preprocessing import MinMaxScaler


sc = MinMaxScaler(feature_range=(0, 1))
sc.fit(df1[['close']])
# Out:
# MinMaxScaler()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm

#   Create a confidence interval for the prediction
confidence_level = 0.95
z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for 95% confidence level

# Create error range for Future Prediction
std_dev = np.std(y_pred_future)  # Standard deviation of future prediction
margin_of_error = z_score * std_dev

# Calculate the confidence interval for Future Prediction
lower_bound = y_pred_future - margin_of_error
upper_bound = y_pred_future + margin_of_error

# Print out the confidence interval value
print("Margin of Error:", margin_of_error)
print("Lower Bound of Future Prediction:", lower_bound)
print("Upper Bound of Future Prediction:", upper_bound)

# Calculate the reliability of the model
mean_prediction = np.mean(y_pred_future)
confidence_interval_range = upper_bound - lower_bound
confidence_score = 1 - (np.mean(confidence_interval_range) / mean_prediction)
print("Confidence Score:", confidence_score)

# Function to calculate confidence interval
def calculate_confidence_interval(predictions, confidence_level=0.95):
    z_score = norm.ppf((1 + confidence_level) / 2)  # Z value for confidence level
    std_dev = np.std(predictions)  # Standard deviation of prediction
    margin_of_error = z_score * std_dev
    lower_bound = predictions - margin_of_error
    upper_bound = predictions + margin_of_error
    return lower_bound, upper_bound, margin_of_error

#   Use the function to calculate the confidence interval for Future Prediction
lower_bound, upper_bound, margin_of_error = calculate_confidence_interval(y_pred_future)

# Convert confidence intervals to DataFrames for plotting convenience
PREDICTIONS_FUTURE_LOWER = pd.DataFrame(lower_bound, columns=['close']).set_index(pd.Series(datelist_future))
PREDICTIONS_FUTURE_UPPER = pd.DataFrame(upper_bound, columns=['close']).set_index(pd.Series(datelist_future))

# Plot a graph with confidence intervals
plt.figure(figsize=(16, 8))

# Plot the training data
tl, = plt.plot(train_data.index, train_data['close'], color='blue', label='Train Data')

# Plot the test data (actual values)
tt, = plt.plot(test_data.index, test_data['close'], color='orange', label='Test Data')

# Plot the validation data (actual values)
vl, = plt.plot(val_data.index, val_data['close'], color='green', label='Validate Data')

# Plot the test data predictions
tp, = plt.plot(test_data.index, y_test_predict, color='red', linestyle='dotted', label='Test Prediction')

# Plot the validation data predictions
vp, = plt.plot(val_data.index, y_val_predict, color='purple', linestyle='dotted', label='Validate Prediction')

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Gold Prices Prediction with Confidence Interval')
plt.legend(handles=[tl, tt, vl, tp, vp, pf])
plt.show()

#Draw a separate graph for the confidence interval
plt.figure(figsize=(16, 8))

# Plot the future predictions
pf, = plt.plot(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE['close'], color='black', linestyle='dashed', label='Future Prediction')

# Plot the confidence interval for future predictions
plt.fill_between(PREDICTIONS_FUTURE.index, PREDICTIONS_FUTURE_LOWER['close'], PREDICTIONS_FUTURE_UPPER['close'], color='gray', alpha=0.3, label='Confidence Interval (95%)')

# Add labels, title, and legend
plt.xlabel('Date')
plt.ylabel('Price')
plt.title('Confidence Interval for Future Predictions')
plt.legend(handles=[pf])
plt.show()
# Out:
# Margin of Error: 178.07480629187629
# Lower Bound of Future Prediction: [[2099.47112729]
#  [2061.96617757]
#  [2026.58194264]
#  [1997.10733205]
#  [1973.34909288]
#  [1954.0977978 ]
#  [1937.8027032 ]
#  [1923.14609349]
#  [1909.27436553]
#  [1895.80635847]
#  [1882.72020641]
#  [1870.19874993]
#  [1858.48695655]
#  [1847.7910599 ]
#  [1838.22642864]
#  [1829.80673763]
#  [1822.46097476]
#  [1816.06086008]
#  [1810.45138863]
#  [1805.47533417]
#  [1800.98914532]
#  [1796.87127544]
#  [1793.02475098]
#  [1789.37425606]
#  [1785.86307818]
#  [1782.44824909]
#  [1779.09714349]
#  [1775.78546593]
#  [1772.49412712]
#  [1769.21056286]]
# Upper Bound of Future Prediction: [[2455.62073987]
#  [2418.11579015]
#  [2382.73155523]
#  [2353.25694464]
#  [2329.49870546]
#  [2310.24741038]
#  [2293.95231578]
#  [2279.29570608]
#  [2265.42397812]
#  [2251.95597105]
#  [2238.86981899]
#  [2226.34836251]
#  [2214.63656913]
#  [2203.94067248]
#  [2194.37604122]
#  [2185.95635021]
#  [2178.61058735]
#  [2172.21047266]
#  [2166.60100121]
#  [2161.62494675]
#  [2157.1387579 ]
#  [2153.02088802]
#  [2149.17436356]
#  [2145.52386865]
#  [2142.01269076]
#  [2138.59786168]
#  [2135.24675607]
#  [2131.93507851]
#  [2128.6437397 ]
#  [2125.36017544]]
# Confidence Score: 0.8258371352770204

# %%
evaluateModel(test_data.values,y_test_predict,val_data.values,y_val_predict)
# Out:
# ** Testing **
# MAE:  14.612896774177825
# MAPE:  0.7977917798584139
# RMSE:  19.063116900684015
#
# ** Validate **
# MAE:  23.50882672731758
# MAPE:  1.0861618040129877
# RMSE:  32.077259562588495

# %%
import pandas as pd

data = {
    "Model": ["LSTM", "LSTM", "LSTM"],
    "Ratio": ["7-2-1", "6-3-1", "5-3-2"],
    "Testing MAE": [12.5019, 13.0908, 18.5606],
    "Testing MAPE": [0.6512, 0.7031, 1.0217],
    "Testing RMSE": [16.8448, 17.2823, 23.9815],
    "Validation MAE": [21.3910, 26.0325, 23.6238],
    "Validation MAPE": [0.9552, 1.1637, 1.0993],
    "Validation RMSE": [28.0878, 32.3465, 32.1555],
}

df = pd.DataFrame(data)

print(df.to_string(index=False))
# Out:
# Model Ratio  Testing MAE  Testing MAPE  Testing RMSE  Validation MAE  Validation MAPE  Validation RMSE
#  LSTM 7-2-1      12.5019        0.6512       16.8448         21.3910           0.9552          28.0878
#  LSTM 6-3-1      13.0908        0.7031       17.2823         26.0325           1.1637          32.3465
#  LSTM 5-3-2      18.5606        1.0217       23.9815         23.6238           1.0993          32.1555
